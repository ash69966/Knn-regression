# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv("/content/car_price_prediction.csv")

df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 19232        Manual         Rear  02-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May        Left wheel     Red        8
# 19234     Automatic        Front  04-May        Left wheel    Grey        4
# 19235     Automatic        Front  04-May        Left wheel   Black        4
# 19236     Automatic        Front  04-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
df.nunique()
# Out:
# ID                  18924
# Price                2315
# Levy                  559
# Manufacturer           65
# Model                1590
# Prod. year             54
# Category               11
# Leather interior        2
# Fuel type               7
# Engine volume         107
# Mileage              7687
# Cylinders              13
# Gear box type           4
# Drive wheels            3
# Doors                   3
# Wheel                   2
# Color                  16
# Airbags                17
# dtype: int64

# %%
desc = ['Price','Prod. year', 'Cylinders', 'Airbags']
df[desc].describe()
# Out:
#               Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   1.855593e+04   2010.912824      4.582991      6.582627
# std    1.905813e+05      5.668673      1.199933      4.320168
# min    1.000000e+00   1939.000000      1.000000      0.000000
# 25%    5.331000e+03   2009.000000      4.000000      4.000000
# 50%    1.317200e+04   2012.000000      4.000000      6.000000
# 75%    2.207500e+04   2015.000000      4.000000     12.000000
# max    2.630750e+07   2020.000000     16.000000     16.000000

# %%
for col in df.columns:
    print(col)
    print(df[f'{col}'].unique())
    print('*'*75)
# Out:
# ID
# [45654403 44731507 45774419 ... 45804997 45793526 45813273]
# ***************************************************************************
# Price
# [13328 16621  8467 ... 56814 63886 22075]
# ***************************************************************************
# Levy
# ['1399' '1018' '-' '862' '446' '891' '761' '751' '394' '1053' '1055'
#  '1079' '810' '2386' '1850' '531' '586' '1249' '2455' '583' '1537' '1288'
#  '915' '1750' '707' '1077' '1486' '1091' '650' '382' '1436' '1194' '503'
#  '1017' '1104' '639' '629' '919' '781' '530' '640' '765' '777' '779' '934'
#  '769' '645' '1185' '1324' '830' '1187' '1111' '760' '642' '1604' '1095'
#  '966' '473' '1138' '1811' '988' '917' '1156' '687' '11714' '836' '1347'
#  '2866' '1646' '259' '609' '697' '585' '475' '690' '308' '1823' '1361'
#  '1273' '924' '584' '2078' '831' '1172' '893' '1872' '1885' '1266' '447'
#  '2148' '1730' '730' '289' '502' '333' '1325' '247' '879' '1342' '1327'
#  '1598' '1514' '1058' '738' '1935' '481' '1522' '1282' '456' '880' '900'
#  '798' '1277' '442' '1051' '790' '1292' '1047' '528' '1211' '1493' '1793'
#  '574' '930' '1998' '271' '706' '1481' '1677' '1661' '1286' '1408' '1090'
#  '595' '1451' '1267' '993' '1714' '878' '641' '749' '1511' '603' '353'
#  '877' '1236' '1141' '397' '784' '1024' '1357' '1301' '770' '922' '1438'
#  '753' '607' '1363' '638' '490' '431' '565' '517' '833' '489' '1760' '986'
#  '1841' '1620' '1360' '474' '1099' '978' '1624' '1946' '1268' '1307' '696'
#  '649' '666' '2151' '551' '800' '971' '1323' '2377' '1845' '1083' '694'
#  '463' '419' '345' '1515' '1505' '2056' '1203' '729' '460' '1356' '876'
#  '911' '1190' '780' '448' '2410' '1848' '1148' '834' '1275' '1028' '1197'
#  '724' '890' '1705' '505' '789' '2959' '518' '461' '1719' '2858' '3156'
#  '2225' '2177' '1968' '1888' '1308' '2736' '1103' '557' '2195' '843'
#  '1664' '723' '4508' '562' '501' '2018' '1076' '1202' '3301' '691' '1440'
#  '1869' '1178' '418' '1820' '1413' '488' '1304' '363' '2108' '521' '1659'
#  '87' '1411' '1528' '3292' '7058' '1578' '627' '874' '1996' '1488' '5679'
#  '1234' '5603' '400' '889' '3268' '875' '949' '2265' '441' '742' '425'
#  '2476' '2971' '614' '1816' '1375' '1405' '2297' '1062' '1113' '420'
#  '2469' '658' '1951' '2670' '2578' '1995' '1032' '994' '1011' '2421'
#  '1296' '155' '494' '426' '1086' '961' '2236' '1829' '764' '1834' '1054'
#  '617' '1529' '2266' '637' '626' '1832' '1016' '2002' '1756' '746' '1285'
#  '2690' '1118' '5332' '980' '1807' '970' '1228' '1195' '1132' '1768'
#  '1384' '1080' '7063' '1817' '1452' '1975' '1368' '702' '1974' '1781'
#  '1036' '944' '663' '364' '1539' '1345' '1680' '2209' '741' '1575' '695'
#  '1317' '294' '1525' '424' '997' '1473' '1552' '2819' '2188' '1668' '3057'
#  '799' '1502' '2606' '552' '1694' '1759' '1110' '399' '1470' '1174' '5877'
#  '1474' '1688' '526' '686' '5908' '1107' '2070' '1468' '1246' '1685' '556'
#  '1533' '1917' '1346' '732' '692' '579' '421' '362' '3505' '1855' '2711'
#  '1586' '3739' '681' '1708' '2278' '1701' '722' '1482' '928' '827' '832'
#  '527' '604' '173' '1341' '3329' '1553' '859' '167' '916' '828' '2082'
#  '1176' '1108' '975' '3008' '1516' '2269' '1699' '2073' '1031' '1503'
#  '2364' '1030' '1442' '5666' '2715' '1437' '2067' '1426' '2908' '1279'
#  '866' '4283' '279' '2658' '3015' '2004' '1391' '4736' '748' '1466' '644'
#  '683' '2705' '1297' '731' '1252' '2216' '3141' '3273' '1518' '1723'
#  '1588' '972' '682' '1094' '668' '175' '967' '402' '3894' '1960' '1599'
#  '2000' '2084' '1621' '714' '1109' '3989' '873' '1572' '1163' '1991'
#  '1716' '1673' '2562' '2874' '965' '462' '605' '1948' '1736' '3518' '2054'
#  '2467' '1681' '1272' '1205' '750' '2156' '2566' '115' '524' '3184' '676'
#  '1678' '612' '328' '955' '1441' '1675' '3965' '2909' '623' '822' '867'
#  '3025' '1993' '792' '636' '4057' '3743' '2337' '2570' '2418' '2472'
#  '3910' '1662' '2123' '2628' '3208' '2080' '3699' '2913' '864' '2505'
#  '870' '7536' '1924' '1671' '1064' '1836' '1866' '4741' '841' '1369'
#  '5681' '3112' '1366' '2223' '1198' '1039' '3811' '3571' '1387' '1171'
#  '1365' '1531' '1590' '11706' '2308' '4860' '1641' '1045' '1901']
# ***************************************************************************
# Manufacturer
# ['LEXUS' 'CHEVROLET' 'HONDA' 'FORD' 'HYUNDAI' 'TOYOTA' 'MERCEDES-BENZ'
#  'OPEL' 'PORSCHE' 'BMW' 'JEEP' 'VOLKSWAGEN' 'AUDI' 'RENAULT' 'NISSAN'
#  'SUBARU' 'DAEWOO' 'KIA' 'MITSUBISHI' 'SSANGYONG' 'MAZDA' 'GMC' 'FIAT'
#  'INFINITI' 'ALFA ROMEO' 'SUZUKI' 'ACURA' 'LINCOLN' 'VAZ' 'GAZ' 'CITROEN'
#  'LAND ROVER' 'MINI' 'DODGE' 'CHRYSLER' 'JAGUAR' 'ISUZU' 'SKODA'
#  'DAIHATSU' 'BUICK' 'TESLA' 'CADILLAC' 'PEUGEOT' 'BENTLEY' 'VOLVO' 'სხვა'
#  'HAVAL' 'HUMMER' 'SCION' 'UAZ' 'MERCURY' 'ZAZ' 'ROVER' 'SEAT' 'LANCIA'
#  'MOSKVICH' 'MASERATI' 'FERRARI' 'SAAB' 'LAMBORGHINI' 'ROLLS-ROYCE'
#  'PONTIAC' 'SATURN' 'ASTON MARTIN' 'GREATWALL']
# ***************************************************************************
# Model
# ['RX 450' 'Equinox' 'FIT' ... 'E 230 124' 'RX 450 F SPORT' 'Prius C aqua']
# ***************************************************************************
# Prod. year
# [2010 2011 2006 2014 2016 2013 2007 1999 1997 2018 2008 2012 2017 2001
#  1995 2009 2000 2019 2015 2004 1998 1990 2005 2003 1985 1996 2002 1993
#  1992 1988 1977 1989 1994 2020 1984 1986 1991 1983 1953 1964 1974 1987
#  1943 1978 1965 1976 1957 1980 1939 1968 1947 1982 1981 1973]
# ***************************************************************************
# Category
# ['Jeep' 'Hatchback' 'Sedan' 'Microbus' 'Goods wagon' 'Universal' 'Coupe'
#  'Minivan' 'Cabriolet' 'Limousine' 'Pickup']
# ***************************************************************************
# Leather interior
# ['Yes' 'No']
# ***************************************************************************
# Fuel type
# ['Hybrid' 'Petrol' 'Diesel' 'CNG' 'Plug-in Hybrid' 'LPG' 'Hydrogen']
# ***************************************************************************
# Engine volume
# ['3.5' '3' '1.3' '2.5' '2' '1.8' '2.4' '4' '1.6' '3.3' '2.0 Turbo'
#  '2.2 Turbo' '4.7' '1.5' '4.4' '3.0 Turbo' '1.4 Turbo' '3.6' '2.3'
#  '1.5 Turbo' '1.6 Turbo' '2.2' '2.3 Turbo' '1.4' '5.5' '2.8 Turbo' '3.2'
#  '3.8' '4.6' '1.2' '5' '1.7' '2.9' '0.5' '1.8 Turbo' '2.4 Turbo'
#  '3.5 Turbo' '1.9' '2.7' '4.8' '5.3' '0.4' '2.8' '3.2 Turbo' '1.1' '2.1'
#  '0.7' '5.4' '1.3 Turbo' '3.7' '1' '2.5 Turbo' '2.6' '1.9 Turbo'
#  '4.4 Turbo' '4.7 Turbo' '0.8' '0.2 Turbo' '5.7' '4.8 Turbo' '4.6 Turbo'
#  '6.7' '6.2' '1.2 Turbo' '3.4' '1.7 Turbo' '6.3 Turbo' '2.7 Turbo' '4.3'
#  '4.2' '2.9 Turbo' '0' '4.0 Turbo' '20' '3.6 Turbo' '0.3' '3.7 Turbo'
#  '5.9' '5.5 Turbo' '0.2' '2.1 Turbo' '5.6' '6' '0.7 Turbo' '0.6 Turbo'
#  '6.8' '4.5' '0.6' '7.3' '0.1' '1.0 Turbo' '6.3' '4.5 Turbo' '0.8 Turbo'
#  '4.2 Turbo' '3.1' '5.0 Turbo' '6.4' '3.9' '5.7 Turbo' '0.9' '0.4 Turbo'
#  '5.4 Turbo' '0.3 Turbo' '5.2' '5.8' '1.1 Turbo']
# ***************************************************************************
# Mileage
# ['186005 km' '192000 km' '200000 km' ... '140607 km' '307325 km'
#  '186923 km']
# ***************************************************************************
# Cylinders
# [ 6.  4.  8.  1. 12.  3.  2. 16.  5.  7.  9. 10. 14.]
# ***************************************************************************
# Gear box type
# ['Automatic' 'Tiptronic' 'Variator' 'Manual']
# ***************************************************************************
# Drive wheels
# ['4x4' 'Front' 'Rear']
# ***************************************************************************
# Doors
# ['04-May' '02-Mar' '>5']
# ***************************************************************************
# Wheel
# ['Left wheel' 'Right-hand drive']
# ***************************************************************************
# Color
# ['Silver' 'Black' 'White' 'Grey' 'Blue' 'Green' 'Red' 'Sky blue' 'Orange'
#  'Yellow' 'Brown' 'Golden' 'Beige' 'Carnelian red' 'Purple' 'Pink']
# ***************************************************************************
# Airbags
# [12  8  2  0  4  6 10  3  1 16  5  7  9 11 14 15 13]
# ***************************************************************************

# %%
df[df['Levy'] == '-']
# Out:
#              ID  Price Levy   Manufacturer      Model  Prod. year  \
# 2      45774419   8467    -          HONDA        FIT        2006
# 9      45756839  26657    -          LEXUS     RX 350        2007
# 11     45814819   8781    -           FORD    Transit        1999
# 12     45815568   3000    -           OPEL     Vectra        1997
# 23     45814106   7840    -           FORD    Transit        2001
# ...         ...    ...  ...            ...        ...         ...
# 19223  44571028   8781    -          DODGE    Caliber        2008
# 19224  45768089  19130    -            KIA  Optima ex        2014
# 19226  45796788   7840    -         NISSAN    Skyline        2003
# 19229  39977395     50    -         TOYOTA      Prius        2008
# 19232  45798355   8467    -  MERCEDES-BENZ    CLK 200        1999
#
#           Category Leather interior Fuel type Engine volume    Mileage  \
# 2        Hatchback               No    Petrol           1.3  200000 km
# 9             Jeep              Yes    Petrol           3.5  128500 km
# 11        Microbus               No       CNG             4       0 km
# 12     Goods wagon               No       CNG           1.6  350000 km
# 23        Microbus               No    Diesel     2.0 Turbo  230000 km
# ...            ...              ...       ...           ...        ...
# 19223    Hatchback               No    Petrol           2.4       0 km
# 19224        Sedan              Yes    Petrol           2.4   35800 km
# 19226        Sedan              Yes    Petrol             3  220000 km
# 19229    Hatchback               No    Hybrid           1.5  150000 km
# 19232        Coupe              Yes       CNG     2.0 Turbo  300000 km
#
#        Cylinders Gear box type Drive wheels   Doors             Wheel   Color  \
# 2            4.0      Variator        Front  04-May  Right-hand drive   Black
# 9            6.0     Automatic          4x4  04-May        Left wheel  Silver
# 11           8.0        Manual         Rear  02-Mar        Left wheel    Blue
# 12           4.0        Manual        Front  04-May        Left wheel   White
# 23           4.0        Manual        Front  02-Mar        Left wheel   White
# ...          ...           ...          ...     ...               ...     ...
# 19223        4.0     Automatic        Front  04-May        Left wheel    Blue
# 19224        4.0     Automatic        Front  04-May        Left wheel   Black
# 19226        6.0     Tiptronic         Rear  04-May  Right-hand drive   White
# 19229        4.0     Automatic        Front  04-May        Left wheel  Silver
# 19232        4.0        Manual         Rear  02-Mar        Left wheel  Silver
#
#        Airbags
# 2            2
# 9           12
# 11           0
# 12           4
# 23           0
# ...        ...
# 19223        4
# 19224       12
# 19226        0
# 19229        6
# 19232        5
#
# [5819 rows x 18 columns]

# %%
# Replacing '-' with null
df['Levy'].replace({'-':np.nan}, inplace = True)
# Converting Levy type to float
df['Levy'] = df['Levy'].astype('float64')

# %%
df['Levy'].fillna(value=df['Levy'].median(), inplace=True)

# %%
df.nunique()
# Out:
# ID                  18924
# Price                2315
# Levy                  558
# Manufacturer           65
# Model                1590
# Prod. year             54
# Category               11
# Leather interior        2
# Fuel type               7
# Engine volume         107
# Mileage              7687
# Cylinders              13
# Gear box type           4
# Drive wheels            3
# Doors                   3
# Wheel                   2
# Color                  16
# Airbags                17
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
# Replacement: Yes >> True , No >> False
df['Leather interior'].replace({'Yes': True, 'No':False}, inplace=True)

# %%
# Making sure that we don miss anything so making everything lower first
df['Engine volume'] = df['Engine volume'].str.lower()

# %%
#rows which has turbo in them and assigning the results to new column Turbo. 
df['Turbo'] = df['Engine volume'].str.contains('turbo')

# %%
# Slicing engine volumes and converting type to float
df['Engine volume'] = df['Engine volume'].str.slice(0,3)
df['Engine volume'] = df['Engine volume'].astype('float64')

# %%
df['Mileage'] = df['Mileage'].str.strip('km')
df['Mileage'] = df['Mileage'].astype('int64')

# %%
df['Doors'].replace({'04-May':4, '02-Mar':2, '>5':5}, inplace=True)

# %%
cars = df.drop('ID', axis=1)

# %%
cars.head()
# Out:
#    Price    Levy Manufacturer    Model  Prod. year   Category  \
# 0  13328  1399.0        LEXUS   RX 450        2010       Jeep
# 1  16621  1018.0    CHEVROLET  Equinox        2011       Jeep
# 2   8467   781.0        HONDA      FIT        2006  Hatchback
# 3   3607   862.0         FORD   Escape        2011       Jeep
# 4  11726   446.0        HONDA      FIT        2014  Hatchback
#
#    Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 0              True    Hybrid            3.5   186005        6.0
# 1             False    Petrol            3.0   192000        6.0
# 2             False    Petrol            1.3   200000        4.0
# 3              True    Hybrid            2.5   168966        4.0
# 4              True    Petrol            1.3    91901        4.0
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags  Turbo
# 0     Automatic          4x4      4        Left wheel  Silver       12  False
# 1     Tiptronic          4x4      4        Left wheel   Black        8  False
# 2      Variator        Front      4  Right-hand drive   Black        2  False
# 3     Automatic          4x4      4        Left wheel   White        0  False
# 4     Automatic        Front      4        Left wheel  Silver        4  False

# %%
def replace_outliers_median(x):
    q1 = np.percentile(x, 25)
    q3 = np.percentile(x, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    x[x < lower_bound] = np.median(x)
    x[x > upper_bound] = np.median(x)
    return x

# Define a function to replace outliers with the mode for categorical variables
def replace_outliers_mode(x):
    mode = x.mode()[0]
    x[x != mode] = mode
    return x

# %%
cars.describe()
# Out:
#               Price          Levy    Prod. year  Engine volume       Mileage  \
# count  1.923700e+04  19237.000000  19237.000000   19237.000000  1.923700e+04
# mean   1.855593e+04    868.773353   2010.912824       2.307990  1.532236e+06
# std    1.905813e+05    390.040440      5.668673       0.877805  4.840387e+07
# min    1.000000e+00     87.000000   1939.000000       0.000000  0.000000e+00
# 25%    5.331000e+03    730.000000   2009.000000       1.800000  7.013900e+04
# 50%    1.317200e+04    781.000000   2012.000000       2.000000  1.260000e+05
# 75%    2.207500e+04    917.000000   2015.000000       2.500000  1.888880e+05
# max    2.630750e+07  11714.000000   2020.000000      20.000000  2.147484e+09
#
#           Cylinders         Doors       Airbags
# count  19237.000000  19237.000000  19237.000000
# mean       4.582991      3.925872      6.582627
# std        1.199933      0.403399      4.320168
# min        1.000000      2.000000      0.000000
# 25%        4.000000      4.000000      4.000000
# 50%        4.000000      4.000000      6.000000
# 75%        4.000000      4.000000     12.000000
# max       16.000000      5.000000     16.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             19237 non-null  int64
#  1   Levy              19237 non-null  float64
#  2   Manufacturer      19237 non-null  object
#  3   Model             19237 non-null  object
#  4   Prod. year        19237 non-null  int64
#  5   Category          19237 non-null  object
#  6   Leather interior  19237 non-null  bool
#  7   Fuel type         19237 non-null  object
#  8   Engine volume     19237 non-null  float64
#  9   Mileage           19237 non-null  int64
#  10  Cylinders         19237 non-null  float64
#  11  Gear box type     19237 non-null  object
#  12  Drive wheels      19237 non-null  object
#  13  Doors             19237 non-null  int64
#  14  Wheel             19237 non-null  object
#  15  Color             19237 non-null  object
#  16  Airbags           19237 non-null  int64
#  17  Turbo             19237 non-null  bool
# dtypes: bool(2), float64(3), int64(5), object(8)
# memory usage: 2.4+ MB

# %%
cars.nunique()
# Out:
# Price               2315
# Levy                 558
# Manufacturer          65
# Model               1590
# Prod. year            54
# Category              11
# Leather interior       2
# Fuel type              7
# Engine volume         65
# Mileage             7687
# Cylinders             13
# Gear box type          4
# Drive wheels           3
# Doors                  3
# Wheel                  2
# Color                 16
# Airbags               17
# Turbo                  2
# dtype: int64

# %%
df = pd.DataFrame(cars, columns = [ 'Levy'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Apply the functions to the data
cars[['Price', 'Levy', 'Mileage']] = cars[['Price', 'Levy', 'Mileage']].apply(replace_outliers_median)

# %%
df = pd.DataFrame(cars, columns = ['Price', 'Levy', 'Mileage'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
cars[['Price', 'Levy', 'Mileage']] = cars[['Price', 'Levy', 'Mileage']].apply(replace_outliers_median)

# %%
df = pd.DataFrame(cars, columns = ['Price', 'Levy', 'Mileage'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
cars[['Price', 'Levy', 'Mileage']] = cars[['Price', 'Levy', 'Mileage']].apply(replace_outliers_median)

# %%
df = pd.DataFrame(cars, columns = ['Price', 'Levy', 'Mileage'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
cars[['Price', 'Mileage']] = cars[['Price',  'Mileage']].apply(replace_outliers_median)

# %%
df = pd.DataFrame(cars, columns = ['Price', 'Levy', 'Mileage'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
cars[['Price']] = cars[['Price']].apply(replace_outliers_median)

# %%
cars[['Price']] = cars[['Price']].apply(replace_outliers_median)

# %%
df = pd.DataFrame(cars, columns = ['Price', 'Levy', 'Mileage'])  

plt.figure(figsize = (5, 20)) 
  
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
cars.shape
# Out:
# (19237, 18)

# %%
cars.describe()
# Out:
#               Price     Levy    Prod. year  Engine volume        Mileage  \
# count  19237.000000  19237.0  19237.000000   19237.000000   19237.000000
# mean   12172.867027    781.0   2010.912824       2.307990  126609.890887
# std     8436.345427      0.0      5.668673       0.877805   76246.731967
# min        1.000000    781.0   1939.000000       0.000000       0.000000
# 25%     5331.000000    781.0   2009.000000       1.800000   70139.000000
# 50%    13172.000000    781.0   2012.000000       2.000000  126000.000000
# 75%    17249.000000    781.0   2015.000000       2.500000  175000.000000
# max    35124.000000    781.0   2020.000000      20.000000  332243.000000
#
#           Cylinders         Doors       Airbags
# count  19237.000000  19237.000000  19237.000000
# mean       4.582991      3.925872      6.582627
# std        1.199933      0.403399      4.320168
# min        1.000000      2.000000      0.000000
# 25%        4.000000      4.000000      4.000000
# 50%        4.000000      4.000000      6.000000
# 75%        4.000000      4.000000     12.000000
# max       16.000000      5.000000     16.000000

# %%
cars[cars['Mileage'] == 0]
# Out:
#        Price   Levy Manufacturer    Model  Prod. year   Category  \
# 11      8781  781.0         FORD  Transit        1999   Microbus
# 24      4704  781.0         OPEL   Vectra        1995      Sedan
# 26       549  781.0        LEXUS   GX 470        2008       Jeep
# 83      8154  781.0        HONDA     Cr-v        1998       Jeep
# 97      4234  781.0        HONDA    Civic        1997  Hatchback
# ...      ...    ...          ...      ...         ...        ...
# 19064   2900  781.0          BMW      320        1994      Sedan
# 19088   2200  781.0      PEUGEOT      406        2001      Sedan
# 19103     30  781.0       NISSAN    Tiida        2006  Hatchback
# 19218     30  781.0       NISSAN     Note        2006  Hatchback
# 19223   8781  781.0        DODGE  Caliber        2008  Hatchback
#
#        Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 11                False       CNG            4.0        0        8.0
# 24                False    Petrol            1.8        0        4.0
# 26                 True    Petrol            4.7        0        8.0
# 83                False    Petrol            2.0        0        4.0
# 97                 True    Petrol            1.4        0        4.0
# ...                 ...       ...            ...      ...        ...
# 19064              True    Petrol            2.0        0        6.0
# 19088             False    Petrol            2.0        0        4.0
# 19103             False    Petrol            1.5        0        4.0
# 19218             False    Petrol            1.3        0        4.0
# 19223             False    Petrol            2.4        0        4.0
#
#       Gear box type Drive wheels  Doors             Wheel  Color  Airbags  \
# 11           Manual         Rear      2        Left wheel   Blue        0
# 24        Automatic        Front      4        Left wheel  Green        4
# 26        Automatic          4x4      4        Left wheel  White        0
# 83        Automatic          4x4      4  Right-hand drive  White        2
# 97           Manual        Front      2        Left wheel   Blue        6
# ...             ...          ...    ...               ...    ...      ...
# 19064        Manual         Rear      4        Left wheel  Green        2
# 19088        Manual        Front      4        Left wheel  White        2
# 19103     Automatic        Front      4  Right-hand drive  Black        4
# 19218     Automatic        Front      4  Right-hand drive  Green        9
# 19223     Automatic        Front      4        Left wheel   Blue        4
#
#        Turbo
# 11     False
# 24     False
# 26     False
# 83     False
# 97     False
# ...      ...
# 19064  False
# 19088  False
# 19103  False
# 19218  False
# 19223  False
#
# [721 rows x 18 columns]

# %%
cars[cars['Engine volume'] == 0]
# Out:
#        Price   Levy   Manufacturer     Model  Prod. year   Category  \
# 2010   13172  781.0          TESLA   Model X        2018      Sedan
# 3105    2430  781.0  MERCEDES-BENZ     C 250        2013      Coupe
# 3516   27356  781.0        HYUNDAI   Elantra        2016      Sedan
# 4814   17663  781.0         TOYOTA      Aqua        2012  Hatchback
# 7022   17663  781.0         TOYOTA      Aqua        2012  Hatchback
# 7685   13172  781.0      SSANGYONG    REXTON        2016       Jeep
# 10603  12231  781.0         TOYOTA     Prius        2010  Hatchback
# 12917      6  781.0  MERCEDES-BENZ     E 350        2016      Sedan
# 14642      3  781.0        PORSCHE  Panamera        2011      Sedan
# 17375     78  781.0  MERCEDES-BENZ   CLS 550        2014      Sedan
#
#        Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 2010               True    Petrol            0.0    81907        6.0
# 3105               True    Petrol            0.0   121600        4.0
# 3516               True       LPG            0.0    65004        4.0
# 4814               True    Petrol            0.0   118000        4.0
# 7022               True    Petrol            0.0   118000        4.0
# 7685               True    Diesel            0.0    73968        4.0
# 10603             False    Hybrid            0.0        0        4.0
# 12917              True    Petrol            0.0    33600        6.0
# 14642              True    Petrol            0.0   196800        6.0
# 17375              True    Petrol            0.0    92800        8.0
#
#       Gear box type Drive wheels  Doors       Wheel   Color  Airbags  Turbo
# 2010      Automatic          4x4      4  Left wheel  Silver       12  False
# 3105      Automatic         Rear      4  Left wheel   White       12  False
# 3516      Automatic        Front      4  Left wheel   White        4  False
# 4814      Automatic        Front      4  Left wheel    Grey        4  False
# 7022      Automatic        Front      4  Left wheel    Grey        4  False
# 7685      Automatic        Front      4  Left wheel   Black        4  False
# 10603     Automatic        Front      4  Left wheel  Golden        0  False
# 12917     Automatic         Rear      4  Left wheel   White       12  False
# 14642     Automatic         Rear      4  Left wheel   Black       12  False
# 17375     Automatic         Rear      4  Left wheel   Black       12  False

# %%
# Replacing '-' with null
cars['Mileage'].replace({0:np.nan}, inplace = True)
# Converting Levy type to float
cars['Mileage'] = cars['Mileage'].astype('float64')

# %%
# Replacing '-' with null
cars['Engine volume'].replace({0:np.nan}, inplace = True)
# Converting Levy type to float
cars['Engine volume'] = cars['Engine volume'].astype('float64')

# %%
cars['Mileage'].fillna(value=cars['Mileage'].median(), inplace=True)
cars['Engine volume'].fillna(value=cars['Engine volume'].median(), inplace=True)

# %%
cars.isnull().sum()
# Out:
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# Turbo               0
# dtype: int64

# %%
cars[cars['Price'] < 200]
# Out:
#        Price   Levy Manufacturer       Model  Prod. year   Category  \
# 27        30  781.0       TOYOTA       Prius        2008      Sedan
# 33       125  781.0       TOYOTA  Highlander        2008      Sedan
# 117       94  781.0        HONDA         FIT        2003  Hatchback
# 214       30  781.0        HONDA         FIT        2002  Hatchback
# 221        3  781.0      HYUNDAI     Elantra        2011      Sedan
# ...      ...    ...          ...         ...         ...        ...
# 19103     30  781.0       NISSAN       Tiida        2006  Hatchback
# 19148     30  781.0        HONDA         FIT        2005  Hatchback
# 19164     60  781.0       TOYOTA       Prius        2013      Sedan
# 19218     30  781.0       NISSAN        Note        2006  Hatchback
# 19229     50  781.0       TOYOTA       Prius        2008  Hatchback
#
#        Leather interior Fuel type  Engine volume   Mileage  Cylinders  \
# 27                False    Hybrid            1.5  169000.0        4.0
# 33                 True    Hybrid            3.3  287274.0        6.0
# 117               False    Petrol            1.5  178000.0        4.0
# 214               False    Petrol            1.5  126000.0        4.0
# 221                True    Petrol            1.8   80000.0        4.0
# ...                 ...       ...            ...       ...        ...
# 19103             False    Petrol            1.5  126000.0        4.0
# 19148             False    Petrol            1.3  169000.0        4.0
# 19164             False    Hybrid            1.8  150000.0        4.0
# 19218             False    Petrol            1.3  126000.0        4.0
# 19229             False    Hybrid            1.5  150000.0        4.0
#
#       Gear box type Drive wheels  Doors             Wheel   Color  Airbags  \
# 27        Automatic        Front      4        Left wheel   White        8
# 33        Automatic          4x4      4        Left wheel   White       12
# 117        Variator        Front      4  Right-hand drive  Silver        4
# 214       Automatic        Front      4  Right-hand drive  Silver        4
# 221       Tiptronic        Front      4        Left wheel    Grey        6
# ...             ...          ...    ...               ...     ...      ...
# 19103     Automatic        Front      4  Right-hand drive   Black        4
# 19148     Automatic        Front      4  Right-hand drive   White        4
# 19164     Automatic        Front      4        Left wheel   White        8
# 19218     Automatic        Front      4  Right-hand drive   Green        9
# 19229     Automatic        Front      4        Left wheel  Silver        6
#
#        Turbo
# 27     False
# 33     False
# 117    False
# 214    False
# 221    False
# ...      ...
# 19103  False
# 19148  False
# 19164  False
# 19218  False
# 19229  False
#
# [654 rows x 18 columns]

# %%
# Get the indices of rows where the continuous value is less than 200
drop_indices = cars[cars['Price'] < 200].index

# Drop the rows using the `drop` method
cars = cars.drop(drop_indices)

# Display the modified data
cars
# Out:
#        Price   Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  781.0          LEXUS   RX 450        2010       Jeep
# 1      16621  781.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467  781.0          HONDA      FIT        2006  Hatchback
# 3       3607  781.0           FORD   Escape        2011       Jeep
# 4      11726  781.0          HONDA      FIT        2014  Hatchback
# ...      ...    ...            ...      ...         ...        ...
# 19232   8467  781.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681  781.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108  781.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  781.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470  781.0        HYUNDAI   Sonata        2012      Sedan
#
#        Leather interior Fuel type  Engine volume   Mileage  Cylinders  \
# 0                  True    Hybrid            3.5  186005.0        6.0
# 1                 False    Petrol            3.0  192000.0        6.0
# 2                 False    Petrol            1.3  200000.0        4.0
# 3                  True    Hybrid            2.5  168966.0        4.0
# 4                  True    Petrol            1.3   91901.0        4.0
# ...                 ...       ...            ...       ...        ...
# 19232              True       CNG            2.0  300000.0        4.0
# 19233              True    Petrol            2.4  161600.0        4.0
# 19234              True    Diesel            2.0  116365.0        4.0
# 19235              True    Diesel            2.0   51258.0        4.0
# 19236              True    Hybrid            2.4  186923.0        4.0
#
#       Gear box type Drive wheels  Doors             Wheel   Color  Airbags  \
# 0         Automatic          4x4      4        Left wheel  Silver       12
# 1         Tiptronic          4x4      4        Left wheel   Black        8
# 2          Variator        Front      4  Right-hand drive   Black        2
# 3         Automatic          4x4      4        Left wheel   White        0
# 4         Automatic        Front      4        Left wheel  Silver        4
# ...             ...          ...    ...               ...     ...      ...
# 19232        Manual         Rear      2        Left wheel  Silver        5
# 19233     Tiptronic        Front      4        Left wheel     Red        8
# 19234     Automatic        Front      4        Left wheel    Grey        4
# 19235     Automatic        Front      4        Left wheel   Black        4
# 19236     Automatic        Front      4        Left wheel   White       12
#
#        Turbo
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 19232   True
# 19233  False
# 19234  False
# 19235  False
# 19236  False
#
# [18583 rows x 18 columns]

# %%
cars.nunique()
# Out:
# Price               1470
# Levy                   1
# Manufacturer          65
# Model               1579
# Prod. year            53
# Category              11
# Leather interior       2
# Fuel type              7
# Engine volume         64
# Mileage             7119
# Cylinders             13
# Gear box type          4
# Drive wheels           3
# Doors                  3
# Wheel                  2
# Color                 16
# Airbags               17
# Turbo                  2
# dtype: int64

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(25,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
cars.columns
# Out:
# Index(['Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year', 'Category',
#        'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags', 'Turbo'],
#       dtype='object')

# %%
PlotBarCharts(inpData=cars, colsToPlot=['Manufacturer','Category'])

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x='Category', y='Price', data=cars)
plt.xlabel('Category')
plt.ylabel('Price')
plt.title('Comparison of Categorical Variable to Continuous Target Variable')

# Show the plot
plt.show()

# %%
top_categories = cars['Manufacturer'].value_counts().nlargest(10).index

# Filter the dataframe to include only the top 10 categories
df_top = cars[cars['Manufacturer'].isin(top_categories)]
plt.figure(figsize=(20, 8))
# Create a bar chart
sns.barplot(x='Manufacturer', y='Price', hue='Category', data=df_top)

# Set the title and labels
plt.title('Comparison of Two Categorical Variables to Continuous Target Variable')
plt.xlabel('Manufacturer')
plt.ylabel('Mean Price')
# Show the plot
plt.show()

# %%
top10_cars = cars['Category'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [cars[cars['Category'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = cars['Manufacturer'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [cars[cars['Manufacturer'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Top10 The Most Frequent Cars')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Top10 Cars' Mean Prices")
plt.show()

# %%
top10_cars = cars['Prod. year'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [cars[cars['Prod. year'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = cars['Manufacturer'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [cars[cars['Manufacturer'] == i]['Mileage'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Top10 The Most Frequent Cars')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Mileage')
plt.title("Top10 Cars' Mean Mileage")
plt.show()

# %%
PlotBarCharts(inpData=cars, colsToPlot=['Fuel type',  'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Turbo'])

# %%
cars.groupby('Doors')['Drive wheels'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
plt.title('Drive wheels Distribution by Doors')
plt.xlabel('Doors')
plt.ylabel('Drive wheels')
plt.show()

# %%
cars.groupby('Fuel type')['Gear box type'].value_counts(normalize=True).unstack().plot(kind='bar')
plt.title('Fuel x Gear box')
plt.xlabel('Fuel Type')
plt.ylabel('Gear box type')
plt.show()

# %%
value_counts = cars['Turbo'].value_counts()

# Create a pie chart
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')

# Set the title
plt.title('Proportions of Turbo cars')

# Show the plot
plt.show()

# %%
value_counts = cars['Wheel'].value_counts()

# Create a pie chart
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')

# Set the title
plt.title('Proportions of Wheel')

# Show the plot
plt.show()

# %%
PlotBarCharts(inpData=cars, colsToPlot=['Cylinders', 'Color', 'Airbags'])

# %%
category_filter = 'Manufacturer'
filtered_data = cars[cars['Airbags'] == 12]

# Get the top 10 categories of the first categorical variable by occurrence count
top_categories = filtered_data['Manufacturer'].value_counts().nlargest(10).index.tolist()

# Filter the data to only include the top 10 categories
filtered_data = filtered_data[filtered_data['Manufacturer'].isin(top_categories)]
plt.figure(figsize=(20, 8))
# Create a count plot
sns.countplot(x='Manufacturer', hue='Airbags', data=filtered_data)

# Set chart title and axis labels
plt.title('Top 10 Manufacturer for Airbags = 12'.format(category_filter))
plt.xlabel('Manufacturer')
plt.ylabel('Count')

# Show the chart
plt.show()

# %%
category_filter = 'Manufacturer'
filtered_data = cars[cars['Cylinders'] == 4]

# Get the top 10 categories of the first categorical variable by occurrence count
top_categories = filtered_data['Manufacturer'].value_counts().nlargest(10).index.tolist()

# Filter the data to only include the top 10 categories
filtered_data = filtered_data[filtered_data['Manufacturer'].isin(top_categories)]
plt.figure(figsize=(20, 8))
# Create a count plot
sns.countplot(x='Manufacturer', hue='Cylinders', data=filtered_data)

# Set chart title and axis labels
plt.title('Top 10 Manufacturer for Cylinders = 4'.format(category_filter))
plt.xlabel('Manufacturer')
plt.ylabel('Count')

# Show the chart
plt.show()

# %%
deleted_df = cars

# %%
# %matplotlib inline

deleted_df.hist(bins=25, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(deleted_df.corr(),annot=True, cbar = True)
plt.title('Correlation Matrix')
plt.show()

# %%
deleted_df.columns
# Out:
# Index(['Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year', 'Category',
#        'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags', 'Turbo'],
#       dtype='object')

# %%
df5 = pd.DataFrame(deleted_df, columns= ['Levy', 'Manufacturer', 'Model', 'Prod. year', 'Category',
       'Leather interior', 'Fuel type','Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
       'Airbags', 'Turbo','Price'])

# %%
df4 = pd.DataFrame(deleted_df, columns= ['Engine volume','Mileage'])

# %%
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler().fit(df4)
res = transformer.transform(df4)

# %%
df4 = pd.DataFrame(res, columns =['Engine volume','Mileage'])

# %%
df4
# Out:
#        Engine volume   Mileage
# 0           2.142857  0.624418
# 1           1.428571  0.686802
# 2          -1.000000  0.770051
# 3           0.714286  0.447108
# 4          -1.000000 -0.354838
# ...              ...       ...
# 18578       0.000000  1.810661
# 18579       0.571429  0.370457
# 18580       0.000000 -0.100263
# 18581       0.000000 -0.777773
# 18582       0.571429  0.633971
#
# [18583 rows x 2 columns]

# %%
deleted_df = pd.concat([df4.reset_index(drop=True), df5.reset_index(drop=True)], axis=1)

# %%
deleted_df
# Out:
#        Engine volume   Mileage   Levy   Manufacturer    Model  Prod. year  \
# 0           2.142857  0.624418  781.0          LEXUS   RX 450        2010
# 1           1.428571  0.686802  781.0      CHEVROLET  Equinox        2011
# 2          -1.000000  0.770051  781.0          HONDA      FIT        2006
# 3           0.714286  0.447108  781.0           FORD   Escape        2011
# 4          -1.000000 -0.354838  781.0          HONDA      FIT        2014
# ...              ...       ...    ...            ...      ...         ...
# 18578       0.000000  1.810661  781.0  MERCEDES-BENZ  CLK 200        1999
# 18579       0.571429  0.370457  781.0        HYUNDAI   Sonata        2011
# 18580       0.000000 -0.100263  781.0        HYUNDAI   Tucson        2010
# 18581       0.000000 -0.777773  781.0      CHEVROLET  Captiva        2007
# 18582       0.571429  0.633971  781.0        HYUNDAI   Sonata        2012
#
#         Category  Leather interior Fuel type  Cylinders Gear box type  \
# 0           Jeep              True    Hybrid        6.0     Automatic
# 1           Jeep             False    Petrol        6.0     Tiptronic
# 2      Hatchback             False    Petrol        4.0      Variator
# 3           Jeep              True    Hybrid        4.0     Automatic
# 4      Hatchback              True    Petrol        4.0     Automatic
# ...          ...               ...       ...        ...           ...
# 18578      Coupe              True       CNG        4.0        Manual
# 18579      Sedan              True    Petrol        4.0     Tiptronic
# 18580       Jeep              True    Diesel        4.0     Automatic
# 18581       Jeep              True    Diesel        4.0     Automatic
# 18582      Sedan              True    Hybrid        4.0     Automatic
#
#       Drive wheels  Doors             Wheel   Color  Airbags  Turbo  Price
# 0              4x4      4        Left wheel  Silver       12  False  13328
# 1              4x4      4        Left wheel   Black        8  False  16621
# 2            Front      4  Right-hand drive   Black        2  False   8467
# 3              4x4      4        Left wheel   White        0  False   3607
# 4            Front      4        Left wheel  Silver        4  False  11726
# ...            ...    ...               ...     ...      ...    ...    ...
# 18578         Rear      2        Left wheel  Silver        5   True   8467
# 18579        Front      4        Left wheel     Red        8  False  15681
# 18580        Front      4        Left wheel    Grey        4  False  26108
# 18581        Front      4        Left wheel   Black        4  False   5331
# 18582        Front      4        Left wheel   White       12  False    470
#
# [18583 rows x 18 columns]

# %%
deleted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18583 entries, 0 to 18582
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Engine volume     18583 non-null  float64
#  1   Mileage           18583 non-null  float64
#  2   Levy              18583 non-null  float64
#  3   Manufacturer      18583 non-null  object
#  4   Model             18583 non-null  object
#  5   Prod. year        18583 non-null  int64
#  6   Category          18583 non-null  object
#  7   Leather interior  18583 non-null  bool
#  8   Fuel type         18583 non-null  object
#  9   Cylinders         18583 non-null  float64
#  10  Gear box type     18583 non-null  object
#  11  Drive wheels      18583 non-null  object
#  12  Doors             18583 non-null  int64
#  13  Wheel             18583 non-null  object
#  14  Color             18583 non-null  object
#  15  Airbags           18583 non-null  int64
#  16  Turbo             18583 non-null  bool
#  17  Price             18583 non-null  int64
# dtypes: bool(2), float64(4), int64(4), object(8)
# memory usage: 2.3+ MB

# %%
deleted_df.nunique()
# Out:
# Engine volume         64
# Mileage             7119
# Levy                   1
# Manufacturer          65
# Model               1579
# Prod. year            53
# Category              11
# Leather interior       2
# Fuel type              7
# Cylinders             13
# Gear box type          4
# Drive wheels           3
# Doors                  3
# Wheel                  2
# Color                 16
# Airbags               17
# Turbo                  2
# Price               1470
# dtype: int64

# %%
deleted_df.columns
# Out:
# Index(['Engine volume', 'Mileage', 'Levy', 'Manufacturer', 'Model',
#        'Prod. year', 'Category', 'Leather interior', 'Fuel type', 'Cylinders',
#        'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color', 'Airbags',
#        'Turbo', 'Price'],
#       dtype='object')

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
# Calling the function to check which categorical variables are correlated with target
# Calling the function to check which categorical variables are correlated with target
CategoricalPredictorList=['Manufacturer', 'Model',
       'Prod. year', 'Category', 'Leather interior', 'Fuel type', 'Cylinders',
       'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color', 'Airbags',
       'Turbo']
FunctionAnova(inpData=deleted_df, 
              TargetVariable='Price', 
              CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# Manufacturer is correlated with Price | P-Value: 7.541390228464435e-288
# Model is correlated with Price | P-Value: 0.0
# Prod. year is correlated with Price | P-Value: 9.912132338732719e-189
# Category is correlated with Price | P-Value: 5.255729369478357e-71
# Leather interior is NOT correlated with Price | P-Value: 0.4824033705613814
# Fuel type is correlated with Price | P-Value: 9.834825322402549e-195
# Cylinders is correlated with Price | P-Value: 3.128834246113269e-26
# Gear box type is correlated with Price | P-Value: 1.8332800706937874e-228
# Drive wheels is correlated with Price | P-Value: 1.611112843795937e-25
# Doors is correlated with Price | P-Value: 4.5169877508623125e-06
# Wheel is correlated with Price | P-Value: 1.2339921133227564e-42
# Color is correlated with Price | P-Value: 1.1521261268098087e-40
# Airbags is correlated with Price | P-Value: 0.0
# Turbo is correlated with Price | P-Value: 2.3628067527121834e-94
# ['Manufacturer',
#  'Model',
#  'Prod. year',
#  'Category',
#  'Fuel type',
#  'Cylinders',
#  'Gear box type',
#  'Drive wheels',
#  'Doors',
#  'Wheel',
#  'Color',
#  'Airbags',
#  'Turbo']

# %%
deleted_df = deleted_df.drop(columns=['Levy'])
deleted_df = deleted_df.drop(columns=['Leather interior'])

# %%
from sklearn.preprocessing import LabelEncoder
# create a label encoder object
le = LabelEncoder()

# apply label encoding to each categorical variable
deleted_df['Gear box type'] = le.fit_transform(deleted_df['Gear box type'])
deleted_df['Fuel type'] = le.fit_transform(deleted_df['Fuel type'])
deleted_df['Wheel'] = le.fit_transform(deleted_df['Wheel'])
deleted_df['Color'] = le.fit_transform(deleted_df['Color'])
deleted_df['Drive wheels'] = le.fit_transform(deleted_df['Drive wheels'])
deleted_df['Category'] = le.fit_transform(deleted_df['Category'])
deleted_df['Manufacturer'] = le.fit_transform(deleted_df['Manufacturer'])
deleted_df['Model'] = le.fit_transform(deleted_df['Model'])

# print the encoded data frame
deleted_df
# Out:
#        Engine volume   Mileage  Manufacturer  Model  Prod. year  Category  \
# 0           2.142857  0.624418            32   1236        2010         4
# 1           1.428571  0.686802             8    654        2011         4
# 2          -1.000000  0.770051            21    680        2006         3
# 3           0.714286  0.447108            16    657        2011         4
# 4          -1.000000 -0.354838            21    680        2014         3
# ...              ...       ...           ...    ...         ...       ...
# 18578       0.000000  1.810661            36    384        1999         1
# 18579       0.571429  0.370457            23   1326        2011         9
# 18580       0.000000 -0.100263            23   1431        2010         4
# 18581       0.000000 -0.777773             8    454        2007         4
# 18582       0.571429  0.633971            23   1326        2012         9
#
#        Fuel type  Cylinders  Gear box type  Drive wheels  Doors  Wheel  Color  \
# 0              2        6.0              0             0      4      0     12
# 1              5        6.0              2             0      4      0      1
# 2              5        4.0              3             1      4      1      1
# 3              2        4.0              0             0      4      0     14
# 4              5        4.0              0             1      4      0     12
# ...          ...        ...            ...           ...    ...    ...    ...
# 18578          0        4.0              1             2      2      0     12
# 18579          5        4.0              2             1      4      0     11
# 18580          1        4.0              0             1      4      0      7
# 18581          1        4.0              0             1      4      0      1
# 18582          2        4.0              0             1      4      0     14
#
#        Airbags  Turbo  Price
# 0           12  False  13328
# 1            8  False  16621
# 2            2  False   8467
# 3            0  False   3607
# 4            4  False  11726
# ...        ...    ...    ...
# 18578        5   True   8467
# 18579        8  False  15681
# 18580        4  False  26108
# 18581        4  False   5331
# 18582       12  False    470
#
# [18583 rows x 16 columns]

# %%
deleted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18583 entries, 0 to 18582
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Engine volume  18583 non-null  float64
#  1   Mileage        18583 non-null  float64
#  2   Manufacturer   18583 non-null  int64
#  3   Model          18583 non-null  int64
#  4   Prod. year     18583 non-null  int64
#  5   Category       18583 non-null  int64
#  6   Fuel type      18583 non-null  int64
#  7   Cylinders      18583 non-null  float64
#  8   Gear box type  18583 non-null  int64
#  9   Drive wheels   18583 non-null  int64
#  10  Doors          18583 non-null  int64
#  11  Wheel          18583 non-null  int64
#  12  Color          18583 non-null  int64
#  13  Airbags        18583 non-null  int64
#  14  Turbo          18583 non-null  bool
#  15  Price          18583 non-null  int64
# dtypes: bool(1), float64(3), int64(12)
# memory usage: 2.1 MB

# %%
deleted_df = deleted_df.reset_index()

# %%
deleted_df.head()
# Out:
#    index  Engine volume   Mileage  Manufacturer  Model  Prod. year  Category  \
# 0      0       2.142857  0.624418            32   1236        2010         4
# 1      1       1.428571  0.686802             8    654        2011         4
# 2      2      -1.000000  0.770051            21    680        2006         3
# 3      3       0.714286  0.447108            16    657        2011         4
# 4      4      -1.000000 -0.354838            21    680        2014         3
#
#    Fuel type  Cylinders  Gear box type  Drive wheels  Doors  Wheel  Color  \
# 0          2        6.0              0             0      4      0     12
# 1          5        6.0              2             0      4      0      1
# 2          5        4.0              3             1      4      1      1
# 3          2        4.0              0             0      4      0     14
# 4          5        4.0              0             1      4      0     12
#
#    Airbags  Turbo  Price
# 0       12  False  13328
# 1        8  False  16621
# 2        2  False   8467
# 3        0  False   3607
# 4        4  False  11726

# %%
df2 = deleted_df.drop(columns=['index'])

# %%
df3 = df2.sample(frac = 1)

# %%
X = np.array(df3.drop(["Price"],1))
print("Shape of X:",X.shape)
print(X)
# Out:
# Shape of X: (18583, 15)
# [[2.142857142857143 0.574302141054658 32 ... 14 12 False]
#  [-0.7142857142857143 0.40583782096308435 58 ... 12 12 False]
#  [-0.7142857142857143 0.11810921199823096 58 ... 12 4 False]
#  ...
#  [2.142857142857143 -0.06889877468196363 36 ... 12 12 False]
#  [-0.5714285714285713 -0.9261427196337053 16 ... 14 8 False]
#  [-0.28571428571428564 0.0 58 ... 1 10 False]]

# %%
y = np.array(df3["Price"])
print("Shape of y:",y.shape)
print(y)
# Out:
# Shape of y: (18583,)
# [  549 11290 14009 ... 16621 14900 11604]

# %%
size = X.shape[0]
X_train = X[:int(0.7 * size),:]
X_test = X[int(0.7 * size):,:]
y_train = y[:int(0.7 * size)]
y_test = y[int(0.7 * size):]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (13008, 15)
# (5575, 15)
# (13008,)
# (5575,)

# %%
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)
y_pred = np.zeros(y_test.shape)
y_train.shape, y_test.shape,y_pred.shape
# Out:
# ((13008, 1), (5575, 1), (5575, 1))

# %%
from sklearn.neighbors import KNeighborsRegressor
RegModel = KNeighborsRegressor(n_neighbors=3)

# %%
print(RegModel)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.model_selection import GridSearchCV
param={'n_neighbors': range(1,50)}
grid_kn=GridSearchCV(estimator=RegModel,param_grid=param,scoring='neg_mean_squared_error',cv=5,verbose=1,n_jobs=-1)
grid_kn.fit(X_train,y_train)
print('Best K For Model is: ',grid_kn.best_params_)
print('Best Score is: ',grid_kn.best_score_)
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# Best K For Model is:  {'n_neighbors': 5}
# Best Score is:  -37368493.989581265

# %%
RegModel = KNeighborsRegressor(n_neighbors=4)

# %%
KNN=RegModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

# %%
from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))
# Out:
# R2 Value: 0.6998586079942954

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
df1 = pd.read_csv("/content/google_play(1).csv")
df2 = pd.read_csv("/content/google_play(2).csv")

df1
# Out:
#           id Reviews Price Content Rating                     Genres  \
# 0          1     159     0       Everyone               Art & Design
# 1          2     967     0       Everyone  Art & Design;Pretend Play
# 2          3   87510     0       Everyone               Art & Design
# 3          4  215644     0           Teen                        NaN
# 4          5     967     0       Everyone                        NaN
# ...      ...     ...   ...            ...                        ...
# 10836  10837      38     0       Everyone                        NaN
# 10837  10838       4     0       Everyone                  Education
# 10838  10839       3     0       Everyone                    Medical
# 10839  10840     114     0     Mature 17+                        NaN
# 10840  10841  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver
# 0       January 7, 2018               1.0.0        4.0.3 and up
# ...

# %%
df2
# Out:
#           id                                                App  \
# 0          1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1          2                                Coloring book moana
# 2          3  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3          4                              Sketch - Draw & Paint
# 4          5              Pixel Draw - Number Art Coloring Book
# ...      ...                                                ...
# 10836  10837                                   Sya9a Maroc - FR
# 10837  10838                   Fr. Mike Schmitz Audio Teachings
# 10838  10839                             Parkinson Exercices FR
# 10839  10840                      The SCP Foundation DB fr nn5n
# 10840  10841      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category Rating Reviews                Size     Installs  \
# 0           ART_AND_DESIGN    4.1     159                 NaN      10,000+
# ...

# %%
df = pd.merge(df1, df2, on=['id','Reviews'])

# %%
df
# Out:
#           id Reviews Price Content Rating                     Genres  \
# 0          1     159     0       Everyone               Art & Design
# 1          2     967     0       Everyone  Art & Design;Pretend Play
# 2          3   87510     0       Everyone               Art & Design
# 3          4  215644     0           Teen                        NaN
# 4          5     967     0       Everyone                        NaN
# ...      ...     ...   ...            ...                        ...
# 10836  10837      38     0       Everyone                        NaN
# 10837  10838       4     0       Everyone                  Education
# 10838  10839       3     0       Everyone                    Medical
# 10839  10840     114     0     Mature 17+                        NaN
# 10840  10841  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0        4.0.3 and up
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10841 non-null  int64
#  1   Reviews         10841 non-null  object
#  2   Price           10841 non-null  object
#  3   Content Rating  10840 non-null  object
#  4   Genres          7812 non-null   object
#  5   Last Updated    10841 non-null  object
#  6   Current Ver     10833 non-null  object
#  7   Android Ver     10838 non-null  object
#  8   App             10841 non-null  object
#  9   Category        10841 non-null  object
#  10  Rating          9454 non-null   object
#  11  Size            5595 non-null   object
#  12  Installs        10841 non-null  object
#  13  Type            8810 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                  id
# count  10841.000000
# mean    5421.000000
# std     3129.671468
# min        1.000000
# 25%     2711.000000
# 50%     5421.000000
# 75%     8131.000000
# max    10841.000000

# %%
df.nunique()
# Out:
# id                10841
# Reviews            6002
# Price                93
# Content Rating        6
# Genres              115
# Last Updated       1378
# Current Ver        2832
# Android Ver          33
# App                9660
# Category             34
# Rating               41
# Size                325
# Installs             22
# Type                  3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                   0
# Reviews              0
# Price                0
# Content Rating       1
# Genres            3029
# Last Updated         0
# Current Ver          8
# Android Ver          3
# App                  0
# Category             0
# Rating            1387
# Size              5246
# Installs             0
# Type              2031
# dtype: int64

# %%
for col in df.columns:
    print(col)
    print(df[f'{col}'].unique())
    print('*'*75)
# Out:
# id
# [    1     2     3 ... 10839 10840 10841]
# ***************************************************************************
# Reviews
# ['159' '967' '87510' ... '603' '1195' '398307']
# ***************************************************************************
# Price
# ['0' '$4.99' '$3.99' '$6.99' '$1.49' '$2.99' '$7.99' '$5.99' '$3.49'
#  '$1.99' '$9.99' '$7.49' '$0.99' '$9.00' '$5.49' '$10.00' '$24.99'
#  '$11.99' '$79.99' '$16.99' '$14.99' '$1.00' '$29.99' '$12.99' '$2.49'
#  '$10.99' '$1.50' '$19.99' '$15.99' '$33.99' '$74.99' '$39.99' '$3.95'
#  '$4.49' '$1.70' '$8.99' '$2.00' '$3.88' '$25.99' '$399.99' '$17.99'
#  '$400.00' '$3.02' '$1.76' '$4.84' '$4.77' '$1.61' '$2.50' '$1.59' '$6.49'
#  '$1.29' '$5.00' '$13.99' '$299.99' '$379.99' '$37.99' '$18.99' '$389.99'
#  '$19.90' '$8.49' '$1.75' '$14.00' '$4.85' '$46.99' '$109.99' '$154.99'
#  '$3.08' '$2.59' '$4.80' '$1.96' '$19.40' '$3.90' '$4.59' '$15.46' '$3.04'
# ...

# %%
df[df['Price'] == 'Everyone']
# Out:
#           id Reviews     Price Content Rating             Genres Last Updated  \
# 10472  10473    3.0M  Everyone            NaN  February 11, 2018       1.0.19
#
#       Current Ver Android Ver                                      App  \
# 10472  4.0 and up         NaN  Life Made WI-Fi Touchscreen Photo Frame
#
#       Category Rating    Size Installs Type
# 10472      1.9   19.0  1,000+     Free    0

# %%
df[df['Price'] == '0']
# Out:
#           id Reviews Price Content Rating                     Genres  \
# 0          1     159     0       Everyone               Art & Design
# 1          2     967     0       Everyone  Art & Design;Pretend Play
# 2          3   87510     0       Everyone               Art & Design
# 3          4  215644     0           Teen                        NaN
# 4          5     967     0       Everyone                        NaN
# ...      ...     ...   ...            ...                        ...
# 10836  10837      38     0       Everyone                        NaN
# 10837  10838       4     0       Everyone                  Education
# 10838  10839       3     0       Everyone                    Medical
# 10839  10840     114     0     Mature 17+                        NaN
# 10840  10841  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0        4.0.3 and up
# ...

# %%
df['Price'].value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: Price, Length: 93, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Free    8139
# Paid     670
# 0          1
# Name: Type, dtype: int64

# %%
df['Type'] = df['Type'].replace('nan', 'Free')

# %%
df['Type'].value_counts()
# Out:
# Free    8139
# Paid     670
# 0          1
# Name: Type, dtype: int64

# %%
df['Type'].fillna(value=df['Type'].mode()[0], inplace=True)

# %%
df['Type'].value_counts()
# Out:
# Free    10170
# Paid      670
# 0           1
# Name: Type, dtype: int64

# %%
# Display all rows where price is not 0 and type is free
selected_rows = df[(df['Price'] != '0') & (df['Type'] == 'Free')]

# Store the indices of the selected rows in a variable
selected_indices = selected_rows.index

# Replace the 'type' values of 'free' with 'paid' for only the rows with the selected indices
df.loc[selected_indices, 'Type'] = 'Paid'

# Display the updated DataFrame
print(df)
# Out:
#           id Reviews Price Content Rating                     Genres  \
# 0          1     159     0       Everyone               Art & Design
# 1          2     967     0       Everyone  Art & Design;Pretend Play
# 2          3   87510     0       Everyone               Art & Design
# 3          4  215644     0           Teen                        NaN
# 4          5     967     0       Everyone                        NaN
# ...      ...     ...   ...            ...                        ...
# 10836  10837      38     0       Everyone                        NaN
# 10837  10838       4     0       Everyone                  Education
# 10838  10839       3     0       Everyone                    Medical
# 10839  10840     114     0     Mature 17+                        NaN
# 10840  10841  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0        4.0.3 and up
# ...

# %%
 df[(df['Price'] != '0') & (df['Type'] == 'Free')]
# Out:
# Empty DataFrame
# Columns: [id, Reviews, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, App, Category, Rating, Size, Installs, Type]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10841 non-null  int64
#  1   Reviews         10841 non-null  object
#  2   Price           10841 non-null  object
#  3   Content Rating  10840 non-null  object
#  4   Genres          7812 non-null   object
#  5   Last Updated    10841 non-null  object
#  6   Current Ver     10833 non-null  object
#  7   Android Ver     10838 non-null  object
#  8   App             10841 non-null  object
#  9   Category        10841 non-null  object
#  10  Rating          9454 non-null   object
#  11  Size            5595 non-null   object
#  12  Installs        10841 non-null  object
#  13  Type            10841 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.5+ MB

# %%
df = df.drop(columns = 'id')

# %%
df
# Out:
#       Reviews Price Content Rating                     Genres  \
# 0         159     0       Everyone               Art & Design
# 1         967     0       Everyone  Art & Design;Pretend Play
# 2       87510     0       Everyone               Art & Design
# 3      215644     0           Teen                        NaN
# 4         967     0       Everyone                        NaN
# ...       ...   ...            ...                        ...
# 10836      38     0       Everyone                        NaN
# 10837       4     0       Everyone                  Education
# 10838       3     0       Everyone                    Medical
# 10839     114     0     Mature 17+                        NaN
# 10840  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0        4.0.3 and up
# 1      January 15, 2018               2.0.0        4.0.3 and up
# ...

# %%
for col in df.columns:
    print(col)
    print(df[f'{col}'].unique())
    print('*'*75)
# Out:
# Reviews
# ['159' '967' '87510' ... '603' '1195' '398307']
# ***************************************************************************
# Price
# ['0' '$4.99' '$3.99' '$6.99' '$1.49' '$2.99' '$7.99' '$5.99' '$3.49'
#  '$1.99' '$9.99' '$7.49' '$0.99' '$9.00' '$5.49' '$10.00' '$24.99'
#  '$11.99' '$79.99' '$16.99' '$14.99' '$1.00' '$29.99' '$12.99' '$2.49'
#  '$10.99' '$1.50' '$19.99' '$15.99' '$33.99' '$74.99' '$39.99' '$3.95'
#  '$4.49' '$1.70' '$8.99' '$2.00' '$3.88' '$25.99' '$399.99' '$17.99'
#  '$400.00' '$3.02' '$1.76' '$4.84' '$4.77' '$1.61' '$2.50' '$1.59' '$6.49'
#  '$1.29' '$5.00' '$13.99' '$299.99' '$379.99' '$37.99' '$18.99' '$389.99'
#  '$19.90' '$8.49' '$1.75' '$14.00' '$4.85' '$46.99' '$109.99' '$154.99'
#  '$3.08' '$2.59' '$4.80' '$1.96' '$19.40' '$3.90' '$4.59' '$15.46' '$3.04'
#  '$4.29' '$2.60' '$3.28' '$4.60' '$28.99' '$2.95' '$2.90' '$1.97'
#  '$200.00' '$89.99' '$2.56' '$30.99' '$3.61' '$394.99' '$1.26' 'Everyone'
#  '$1.20' '$1.04']
# ...

# %%
df['Price'].value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: Price, Length: 93, dtype: int64

# %%
df['Price'] = df['Price'].replace('Everyone', '0')

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df['Content Rating'] = df['Content Rating'].replace('Unrated','Everyone')

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
df['Category'] = df['Category'].replace('1.9', 'FAMILY')

# %%
df['Rating'].value_counts()
# Out:
# 4.4     1046
# 4.3     1023
# 4.5      975
# 4.2      906
# 4.6      782
# 4.1      671
# ?        587
# 4.0      533
# 4.7      480
# 3.9      366
# 3.8      288
# 5.0      260
# 3.7      227
# 4.8      220
# 3.6      163
# 3.5      155
# 3.4      121
# 3.3       96
# 4.9       80
# 3.0       79
# 3.1       66
# 3.2       60
# 2.8       41
# 2.9       40
# 2.6       23
# 2.7       22
# 2.5       21
# 2.4       19
# 2.3       18
# 1.0       15
# 2.0       12
# 1.9       12
# 2.2       12
# 1.8        8
# 1.7        8
# 2.1        7
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
df['Rating'] = df['Rating'].replace('?',np.nan)

# %%
df['Rating'] = df['Rating'].replace('19.0','1.9')

# %%
df['Installs'].value_counts()
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: Installs, dtype: int64

# %%
df['Installs'] = df['Installs'].replace('Free','1,000,000+')

# %%
df['Installs'].value_counts()
# Out:
# 1,000,000+        1580
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %%
df
# Out:
#       Reviews Price Content Rating                     Genres  \
# 0         159     0       Everyone               Art & Design
# 1         967     0       Everyone  Art & Design;Pretend Play
# 2       87510     0       Everyone               Art & Design
# 3      215644     0           Teen                        NaN
# 4         967     0       Everyone                        NaN
# ...       ...   ...            ...                        ...
# 10836      38     0       Everyone                        NaN
# 10837       4     0       Everyone                  Education
# 10838       3     0       Everyone                    Medical
# 10839     114     0     Mature 17+                        NaN
# 10840  398307     0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0        4.0.3 and up
# 1      January 15, 2018               2.0.0        4.0.3 and up
# ...

# %%
df['Price'] = df['Price'].str.replace('$', '')

# %%
df['Last Updated'].nunique()
# Out:
# 1378

# %%
df['Android Ver'] = df['Android Ver'].str.replace('and', '')
df['Android Ver'] = df['Android Ver'].str.replace('up', '')

# %%
for col in df.columns:
    print(col)
    print(df[f'{col}'].unique())
    print('*'*75)
# Out:
# Reviews
# ['159' '967' '87510' ... '603' '1195' '398307']
# ***************************************************************************
# Price
# ['0' '4.99' '3.99' '6.99' '1.49' '2.99' '7.99' '5.99' '3.49' '1.99' '9.99'
#  '7.49' '0.99' '9.00' '5.49' '10.00' '24.99' '11.99' '79.99' '16.99'
#  '14.99' '1.00' '29.99' '12.99' '2.49' '10.99' '1.50' '19.99' '15.99'
#  '33.99' '74.99' '39.99' '3.95' '4.49' '1.70' '8.99' '2.00' '3.88' '25.99'
#  '399.99' '17.99' '400.00' '3.02' '1.76' '4.84' '4.77' '1.61' '2.50'
#  '1.59' '6.49' '1.29' '5.00' '13.99' '299.99' '379.99' '37.99' '18.99'
#  '389.99' '19.90' '8.49' '1.75' '14.00' '4.85' '46.99' '109.99' '154.99'
#  '3.08' '2.59' '4.80' '1.96' '19.40' '3.90' '4.59' '15.46' '3.04' '4.29'
#  '2.60' '3.28' '4.60' '28.99' '2.95' '2.90' '1.97' '200.00' '89.99' '2.56'
#  '30.99' '3.61' '394.99' '1.26' '1.20' '1.04']
# ***************************************************************************
# Content Rating
# ...

# %%
df['Price'] = df['Price'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Reviews         10841 non-null  object
#  1   Price           10841 non-null  float64
#  2   Content Rating  10840 non-null  object
#  3   Genres          7812 non-null   object
#  4   Last Updated    10841 non-null  object
#  5   Current Ver     10833 non-null  object
#  6   Android Ver     10838 non-null  object
#  7   App             10841 non-null  object
#  8   Category        10841 non-null  object
#  9   Rating          8867 non-null   object
#  10  Size            5595 non-null   object
#  11  Installs        10841 non-null  object
#  12  Type            10841 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# Reviews           6002
# Price               92
# Content Rating       5
# Genres             115
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# App               9660
# Category            33
# Rating              39
# Size               325
# Installs            21
# Type                 3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Reviews              0
# Price                0
# Content Rating       1
# Genres            3029
# Last Updated         0
# Current Ver          8
# Android Ver          3
# App                  0
# Category             0
# Rating            1974
# Size              5246
# Installs             0
# Type                 0
# dtype: int64

# %%
df['Content Rating'].fillna(value=df['Content Rating'].mode()[0], inplace=True)
df['Genres'].fillna(value=df['Genres'].mode()[0], inplace=True)
df['Current Ver'].fillna(value=df['Current Ver'].mode()[0], inplace=True)
df['Android Ver'].fillna(value=df['Android Ver'].mode()[0], inplace=True)
df['Rating'].fillna(value=df['Rating'].mode()[0], inplace=True)
df['Size'].fillna(value=df['Size'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Reviews           0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# App               0
# Category          0
# Rating            0
# Size              0
# Installs          0
# Type              0
# dtype: int64

# %%
df
# Out:
#       Reviews  Price Content Rating                     Genres  \
# 0         159    0.0       Everyone               Art & Design
# 1         967    0.0       Everyone  Art & Design;Pretend Play
# 2       87510    0.0       Everyone               Art & Design
# 3      215644    0.0           Teen                      Tools
# 4         967    0.0       Everyone                      Tools
# ...       ...    ...            ...                        ...
# 10836      38    0.0       Everyone                      Tools
# 10837       4    0.0       Everyone                  Education
# 10838       3    0.0       Everyone                    Medical
# 10839     114    0.0     Mature 17+                      Tools
# 10840  398307    0.0       Everyone                  Lifestyle
#
#            Last Updated         Current Ver         Android Ver  \
# 0       January 7, 2018               1.0.0             4.0.3
# 1      January 15, 2018               2.0.0             4.0.3
# ...

# %%
df['Android Ver'] = df['Android Ver'].str.replace('W', '')

# %%
from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import StandardScaler, OneHotEncoder
# create a label encoder object
le = LabelEncoder()

# apply label encoding to each categorical variable
df['Genres'] = le.fit_transform(df['Genres'])
df['Last Updated'] = le.fit_transform(df['Last Updated'])
df['Current Ver'] = le.fit_transform(df['Current Ver'])
df['App'] = le.fit_transform(df['App'])
df['Size'] = le.fit_transform(df['Size'])
df['Content Rating'] = le.fit_transform(df['Content Rating'])
df['Category'] = le.fit_transform(df['Category'])
df['Rating'] = le.fit_transform(df['Rating'])
df['Android Ver'] = le.fit_transform(df['Android Ver'])
df['Installs'] = le.fit_transform(df['Installs'])
df['Type'] = le.fit_transform(df['Type'])

# %%
df['Content Rating'] = df['Content Rating'].astype('category')
df['Android Ver'] = df['Android Ver'].astype('category')
df['Category'] = df['Category'].astype('category')
df['Rating'] = df['Rating'].astype('category')
df['Installs'] = df['Installs'].astype('category')

# %%
df['Genres'] = df['Genres'].astype('category')
df['Last Updated'] = df['Last Updated'].astype('category')
df['Current Ver'] = df['Current Ver'].astype('category')
df['App'] = df['App'].astype('category')
df['Size'] = df['Size'].astype('category')
df['Type'] = df['Type'].astype('category')

# %%
df
# Out:
#       Reviews  Price Content Rating Genres Last Updated Current Ver  \
# 0         159    0.0              1      9          561         118
# 1         967    0.0              1     12          481        1018
# 2       87510    0.0              1      9          116         464
# 3      215644    0.0              4    105          824        2765
# 4         967    0.0              1    105          756         277
# ...       ...    ...            ...    ...          ...         ...
# 10836      38    0.0              1    105          645         638
# 10837       4    0.0              1     38          691         113
# 10838       3    0.0              1     70          505         113
# 10839     114    0.0              3    105          496        2765
# 10840  398307    0.0              1     67          646        2765
#
#       Android Ver   App Category Rating Size Installs Type
# 0              14  6963        0     29  324        7    1
# ...

# %%
df['Android Ver'].value_counts()
# Out:
# 16    2454
# 14    1501
# 13    1375
# 31    1362
# 20     992
# 8      652
# 21     601
# 18     394
# 9      281
# 6      244
# 19     243
# 10     241
# 5      134
# 2      116
# 26      60
# 27      42
# 12      36
# 3       32
# 25      24
# 1       20
# 11      10
# 4        7
# 30       6
# 29       3
# 24       2
# 15       2
# 0        2
# 22       1
# 23       1
# 17       1
# 7        1
# 28       1
# Name: Android Ver, dtype: int64

# %%
df.head(10)
# Out:
#   Reviews  Price Content Rating Genres Last Updated Current Ver Android Ver  \
# 0     159    0.0              1      9          561         118          14
# 1     967    0.0              1     12          481        1018          14
# 2   87510    0.0              1      9          116         464          14
# 3  215644    0.0              4    105          824        2765          18
# 4     967    0.0              1    105          756         277          20
# 5     167    0.0              1    105          900         113           8
# 6     178    0.0              1      9           75         277          14
# 7   36815    0.0              1      9          725        2391          18
# 8   13791    0.0              1      9         1316        1455          10
# 9     121    0.0              1     11          669        1429          14
#
#     App Category Rating Size Installs Type
# 0  6963        0     29  324        7    1
# 1  2632        0     27  324       19    1
# ...

# %%
df.isnull().sum()
# Out:
# Reviews           0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# App               0
# Category          0
# Rating            0
# Size              0
# Installs          0
# Type              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Reviews         10841 non-null  object
#  1   Price           10841 non-null  float64
#  2   Content Rating  10841 non-null  category
#  3   Genres          10841 non-null  category
#  4   Last Updated    10841 non-null  category
#  5   Current Ver     10841 non-null  category
#  6   Android Ver     10841 non-null  category
#  7   App             10841 non-null  category
#  8   Category        10841 non-null  category
#  9   Rating          10841 non-null  category
#  10  Size            10841 non-null  category
#  11  Installs        10841 non-null  category
#  12  Type            10841 non-null  category
# dtypes: category(11), float64(1), object(1)
# memory usage: 1.1+ MB

# %%
top10_cars = df['Category'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['Category'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['Rating'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['Category'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Rating')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Rating and its Mean Prices")
plt.show()

# %%
top10_cars = df['Installs'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['Installs'] == i]['Price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Installs')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Installs and its Mean Prices")
plt.show()

# %%
df.columns
# Out:
# Index(['Reviews', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'App', 'Category', 'Rating', 'Size',
#        'Installs', 'Type'],
#       dtype='object')

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
# Calling the function to check which categorical variables are correlated with target
# Calling the function to check which categorical variables are correlated with target
CategoricalPredictorList=['Reviews','Content Rating', 'Genres', 'Last Updated',
       'Current Ver', 'Android Ver', 'App', 'Category', 'Rating', 'Size',
       'Installs', 'Type']
FunctionAnova(inpData=df, 
              TargetVariable= 'Price', 
              CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# Reviews is NOT correlated with Price | P-Value: 0.9999999999999999
# Content Rating is NOT correlated with Price | P-Value: 0.4421311620180275
# Genres is NOT correlated with Price | P-Value: 0.7507536026555974
# Last Updated is NOT correlated with Price | P-Value: 0.9999955206097053
# Current Ver is NOT correlated with Price | P-Value: 0.9999999999999999
# Android Ver is NOT correlated with Price | P-Value: 0.44671867312618263
# App is correlated with Price | P-Value: 0.0
# Category is correlated with Price | P-Value: 8.32768083574427e-15
# Rating is NOT correlated with Price | P-Value: 0.0917415693871774
# Size is correlated with Price | P-Value: 2.966936744341204e-50
# Installs is correlated with Price | P-Value: 3.7177759032125698e-84
# Type is correlated with Price | P-Value: 1.370433393966033e-126
# ['App', 'Category', 'Size', 'Installs', 'Type']

# %%
SelectedColumns=['App', 'Category', 'Size', 'Installs', 'Type','Price']

# Selecting final columns
df=df[SelectedColumns]
df.head()
# Out:
#     App Category Size Installs Type  Price
# 0  6963        0  324        7    1    0.0
# 1  2632        0  324       19    1    0.0
# 2  8657        0  262       14    1    0.0
# 3  7828        0   73       17    1    0.0
# 4  7023        0  324       10    1    0.0

# %%
df3 = df#.sample(frac = 1)

# %%
X = np.array(df3.drop(["Price"],1))
print("Shape of X:",X.shape)
print(X)
# Out:
# Shape of X: (10841, 5)
# [[6963    0  324    7    1]
#  [2632    0  324   19    1]
#  [8657    0  262   14    1]
#  ...
#  [6892   20  293    3    1]
#  [8395    3  324    3    1]
#  [9487   18   39    8    1]]

# %%
y = np.array(df3["Price"])
print("Shape of y:",y.shape)
print(y)
# Out:
# Shape of y: (10841,)
# [0. 0. 0. ... 0. 0. 0.]

# %%
size = X.shape[0]
X_train = X[:int(0.7 * size),:]
X_test = X[int(0.7 * size):,:]
y_train = y[:int(0.7 * size)]
y_test = y[int(0.7 * size):]

# %%
#Standardizing the X_train and X_test daatsets
mu = np.mean(X_train, 0)
sigma = np.std(X_train, 0)

X_train = (X_train - mu ) / sigma

#We use the same mean and SD as the one of X_train as we dont know the mean of X_test
X_test = (X_test - mu ) / sigma

#Standardizing the y_train data
mu_y = np.mean(y_train, 0)
sigma_y = np.std(y_train, 0, ddof = 0)

y_train = (y_train - mu_y ) / sigma_y

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7588, 5)
# (3253, 5)
# (7588,)
# (3253,)

# %%
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)
y_pred = np.zeros(y_test.shape)
y_train.shape, y_test.shape,y_pred.shape
# Out:
# ((7588, 1), (3253, 1), (3253, 1))

# %%
n_neigh = 13
for row in range(len(X_test)):
    euclidian_distance = np.sqrt(np.sum((X_train - X_test[row])**2, axis = 1 ))
    y_pred[row] = np.mean(y_train[np.argsort(euclidian_distance, axis = 0)[:n_neigh]])* sigma_y + mu_y
    
#Finding the root mean squared error 

RMSE = np.sqrt(np.mean((y_pred - y_test)**2))
print(RMSE)
# Out:
# 11.006305081561722

# %%
# Calculate mean absolute error
mae = np.mean(np.abs(y_test - y_pred))

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 1.324636193809265

# %%
# We are setting a range of K values and calculating the RMSE for each of them. This way we can chose the optimal K value
k_list = [x for x in range(1,50,1)]

# Calculating the distance matrix using numpy broadcasting technique 
distance = np.sqrt(((X_train[:, :, None] - X_test[:, :, None].T) ** 2).sum(1))

#Sorting each data points of the distance matrix to reduce computational effort 
sorted_distance = np.argsort(distance, axis = 0)

#The knn function takes in the sorted distance and returns the RMSE of the 
def knn(X_train,X_test,y_train,y_test,sorted_distance,k):
    y_pred = np.zeros(y_test.shape)
    for row in range(len(X_test)):
        
        #Transforming the y_train values to adjust the scale. 
        y_pred[row] = np.mean(y_train[sorted_distance[:,row][:k]])* sigma_y + mu_y

    RMSE = np.sqrt(np.mean((y_test - y_pred)**2))
    return RMSE

#Storing the RMSE values in a list for each k value 
rmse_list = []
for i in k_list:
    rmse_list.append(knn(X_train,X_test,y_train,y_test,sorted_distance,i))

# %%
#Finding the optimal K value
min_rmse_k_value = k_list[rmse_list.index(min(rmse_list))]

#Finding the lowest possible RMSE
optimal_RMSE = knn(X_train,X_test,y_train,y_test,sorted_distance,min_rmse_k_value)
optimal_RMSE
# Out:
# 10.559448601968523

# %%
min_rmse_k_value
# Out:
# 28

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score,mean_absolute_error

print(np.sqrt(mean_squared_error(y_test,y_pred))) 
r2scr = print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 11.006305081561722
# -0.059104152929502884
# 1.324636193809265

# %%
from sklearn.neighbors import KNeighborsRegressor
RegModel = KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.model_selection import GridSearchCV
param={'n_neighbors': range(1,50)}
grid_kn=GridSearchCV(estimator=RegModel,param_grid=param,scoring='neg_mean_squared_error',cv=5,verbose=1,n_jobs=-1)
grid_kn.fit(X_train,y_train)
print('Best K For Model is: ',grid_kn.best_params_)
print('Best Score is: ',grid_kn.best_score_)
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# Best K For Model is:  {'n_neighbors': 49}
# Best Score is:  -1.0064760737127776

# %%
KNN=RegModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

# %%
from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))
# Out:
# R2 Value: 0.35165399891841165

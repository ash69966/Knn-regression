# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
df1 = pd.read_csv("/content/house(1).csv")
df2 = pd.read_csv("/content/house(2).csv")

df1
# Out:
#                id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7129300520              0      1955             0    98178  47.5112
# 1      6414100192            400      1951          1991    98125  47.7210
# 2      5631500400              0      1933             0    98028  47.7379
# 3      2487200875            910      1965             0    98136  47.5208
# 4      1954400510              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608   263000018              0      2009             0    98103  47.6993
# 21609  6600060120              0      2014             0    98146  47.5107
# 21610  1523300141              0      2009             0    98144  47.5944
# 21611   291310100              0      2004             0    98027  47.5345
# 21612  1523300157              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 9 columns]

# %%
df2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0        NaN
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0        NaN
# 3      2487200875  20141209T000000  604000.0       4.0        NaN
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0        NaN
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       NaN        NaN
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors waterfront  view  condition  grade  \
# 0             1180      5650     NaN          0     0          3      7
# 1             2570      7242     2.0          0     0          3      7
# 2              770     10000     NaN          0     0          3      6
# 3             1960      5000     NaN          0     0          5      7
# 4             1680      8080     1.0          0     0          3      8
# ...            ...       ...     ...        ...   ...        ...    ...
# 21608         1530      1131     3.0          0     0          3      8
# 21609         2310      5813     2.0          0     0          3      8
# 21610         1020      1350     2.0          0     0          3      7
# 21611         1600      2388     2.0          0     0          3      8
# 21612         1020      1076     2.0          0     0          3      7
#
#        sqft_above
# 0            1180
# 1            2170
# 2             770
# 3            1050
# 4            1680
# ...           ...
# 21608        1530
# 21609        2310
# 21610        1020
# 21611        1600
# 21612        1020
#
# [21613 rows x 13 columns]

# %%
df = pd.merge(df1, df2, on=['id'])

# %%
df
# Out:
#                id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7129300520              0      1955             0    98178  47.5112
# 1      6414100192            400      1951          1991    98125  47.7210
# 2      5631500400              0      1933             0    98028  47.7379
# 3      2487200875            910      1965             0    98136  47.5208
# 4      1954400510              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21964   263000018              0      2009             0    98103  47.6993
# 21965  6600060120              0      2014             0    98146  47.5107
# 21966  1523300141              0      2009             0    98144  47.5944
# 21967   291310100              0      2004             0    98027  47.5345
# 21968  1523300157              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15             date  ...  bedrooms  \
# 0     -122.257           1340        5650  20141013T000000  ...       3.0
# 1     -122.319           1690        7639  20141209T000000  ...       3.0
# 2     -122.233           2720        8062  20150225T000000  ...       2.0
# 3     -122.393           1360        5000  20141209T000000  ...       4.0
# 4     -122.045           1800        7503  20150218T000000  ...       3.0
# ...        ...            ...         ...              ...  ...       ...
# 21964 -122.346           1530        1509  20140521T000000  ...       3.0
# 21965 -122.362           1830        7200  20150223T000000  ...       4.0
# 21966 -122.299           1020        2007  20140623T000000  ...       NaN
# 21967 -122.069           1410        1287  20150116T000000  ...       3.0
# 21968 -122.299           1020        1357  20141015T000000  ...       2.0
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront view  condition  \
# 0            NaN         1180      5650     NaN           0    0          3
# 1           2.25         2570      7242     2.0           0    0          3
# 2            NaN          770     10000     NaN           0    0          3
# 3            NaN         1960      5000     NaN           0    0          5
# 4           2.00         1680      8080     1.0           0    0          3
# ...          ...          ...       ...     ...         ...  ...        ...
# 21964        NaN         1530      1131     3.0           0    0          3
# 21965       2.50         2310      5813     2.0           0    0          3
# 21966        NaN         1020      1350     2.0           0    0          3
# 21967       2.50         1600      2388     2.0           0    0          3
# 21968       0.75         1020      1076     2.0           0    0          3
#
#        grade  sqft_above
# 0          7        1180
# 1          7        2170
# 2          6         770
# 3          7        1050
# 4          8        1680
# ...      ...         ...
# 21964      8        1530
# 21965      8        2310
# 21966      7        1020
# 21967      8        1600
# 21968      7        1020
#
# [21969 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21969 entries, 0 to 21968
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21969 non-null  int64
#  1   sqft_basement  21969 non-null  int64
#  2   yr_built       21969 non-null  int64
#  3   yr_renovated   21969 non-null  int64
#  4   zipcode        21969 non-null  int64
#  5   lat            21969 non-null  float64
#  6   long           21969 non-null  float64
#  7   sqft_living15  21969 non-null  int64
#  8   sqft_lot15     21969 non-null  int64
#  9   date           21969 non-null  object
#  10  price          21969 non-null  float64
#  11  bedrooms       15273 non-null  float64
#  12  bathrooms      14353 non-null  float64
#  13  sqft_living    21969 non-null  int64
#  14  sqft_lot       21969 non-null  int64
#  15  floors         17107 non-null  float64
#  16  waterfront     21969 non-null  object
#  17  view           21969 non-null  int64
#  18  condition      21969 non-null  int64
#  19  grade          21969 non-null  int64
#  20  sqft_above     21969 non-null  int64
# dtypes: float64(6), int64(13), object(2)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# bedrooms         6696
# bathrooms        7616
# sqft_living         0
# sqft_lot            0
# floors           4862
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# dtype: int64

# %%
df.nunique()
# Out:
# id               21436
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# date               372
# price             4028
# bedrooms            12
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           3
# view                 5
# condition            5
# grade               12
# sqft_above         946
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21969 entries, 0 to 21968
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21969 non-null  int64
#  1   sqft_basement  21969 non-null  int64
#  2   yr_built       21969 non-null  int64
#  3   yr_renovated   21969 non-null  int64
#  4   zipcode        21969 non-null  int64
#  5   lat            21969 non-null  float64
#  6   long           21969 non-null  float64
#  7   sqft_living15  21969 non-null  int64
#  8   sqft_lot15     21969 non-null  int64
#  9   date           21969 non-null  object
#  10  price          21969 non-null  float64
#  11  bedrooms       15273 non-null  float64
#  12  bathrooms      14353 non-null  float64
#  13  sqft_living    21969 non-null  int64
#  14  sqft_lot       21969 non-null  int64
#  15  floors         17107 non-null  float64
#  16  waterfront     21969 non-null  object
#  17  view           21969 non-null  int64
#  18  condition      21969 non-null  int64
#  19  grade          21969 non-null  int64
#  20  sqft_above     21969 non-null  int64
# dtypes: float64(6), int64(13), object(2)
# memory usage: 3.7+ MB

# %%
df['floors'].value_counts()
# Out:
# 1.0    8485
# 2.0    6513
# 1.5    1498
# 3.0     476
# 2.5     128
# 3.5       7
# Name: floors, dtype: int64

# %%
df['floors'] = df['floors'].replace(2.5, 3)
df['floors'] = df['floors'].replace(1.5, 2)
df['floors'] = df['floors'].replace(3.5, 4)

# %%
df['floors'].value_counts()
# Out:
# 1.0    8485
# 2.0    8011
# 3.0     604
# 4.0       7
# Name: floors, dtype: int64

# %%
df['floors'].median()
# Out:
# 2.0

# %%
df['bedrooms'].value_counts()
# Out:
# 3.0     6933
# 4.0     4816
# 2.0     1955
# 5.0     1154
# 6.0      212
# 1.0      153
# 7.0       26
# 8.0        9
# 0.0        9
# 9.0        4
# 11.0       1
# 10.0       1
# Name: bedrooms, dtype: int64

# %%
df['bedrooms'].median()
# Out:
# 3.0

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    3553
# 1.00    2614
# 1.75    2037
# 2.25    1340
# 2.00    1272
# 1.50     968
# 2.75     770
# 3.00     506
# 3.50     467
# 3.25     395
# 3.75      96
# 4.00      88
# 4.50      68
# 4.25      61
# 0.75      45
# 4.75      14
# 5.00      11
# 5.50       9
# 5.25       9
# 6.00       6
# 0.00       6
# 1.25       6
# 5.75       3
# 8.00       2
# 0.50       2
# 6.75       1
# 7.50       1
# 7.75       1
# 6.25       1
# 6.50       1
# Name: bathrooms, dtype: int64

# %%
df['bathrooms'] = round(df['bathrooms'])

# %%
df['bathrooms'].value_counts()
# Out:
# 2.0    9170
# 1.0    2665
# 3.0    1671
# 4.0     780
# 5.0      34
# 6.0      20
# 0.0       8
# 8.0       4
# 7.0       1
# Name: bathrooms, dtype: int64

# %%
null_cols = ['bathrooms','bedrooms','floors']

# %%
#df['floors'] = df['floors'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21969 entries, 0 to 21968
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21969 non-null  int64
#  1   sqft_basement  21969 non-null  int64
#  2   yr_built       21969 non-null  int64
#  3   yr_renovated   21969 non-null  int64
#  4   zipcode        21969 non-null  int64
#  5   lat            21969 non-null  float64
#  6   long           21969 non-null  float64
#  7   sqft_living15  21969 non-null  int64
#  8   sqft_lot15     21969 non-null  int64
#  9   date           21969 non-null  object
#  10  price          21969 non-null  float64
#  11  bedrooms       15273 non-null  float64
#  12  bathrooms      14353 non-null  float64
#  13  sqft_living    21969 non-null  int64
#  14  sqft_lot       21969 non-null  int64
#  15  floors         17107 non-null  float64
#  16  waterfront     21969 non-null  object
#  17  view           21969 non-null  int64
#  18  condition      21969 non-null  int64
#  19  grade          21969 non-null  int64
#  20  sqft_above     21969 non-null  int64
# dtypes: float64(6), int64(13), object(2)
# memory usage: 3.7+ MB

# %%
#df['bedrooms'].fillna(value=df['bedrooms'].median(), inplace=True)

# %%
#df['bathrooms'].fillna(value=df['bathrooms'].median(), inplace=True)

# %%
#df['floors'].fillna(value=df['floors'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                  0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# bedrooms         6696
# bathrooms        7616
# sqft_living         0
# sqft_lot            0
# floors           4862
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# dtype: int64

# %%
df['floors'].value_counts()
# Out:
# 1.0    8485
# 2.0    8011
# 3.0     604
# 4.0       7
# Name: floors, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat',
#        'long', 'sqft_living15', 'sqft_lot15', 'date', 'price', 'bedrooms',
#        'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'sqft_above'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21969 entries, 0 to 21968
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21969 non-null  int64
#  1   sqft_basement  21969 non-null  int64
#  2   yr_built       21969 non-null  int64
#  3   yr_renovated   21969 non-null  int64
#  4   zipcode        21969 non-null  int64
#  5   lat            21969 non-null  float64
#  6   long           21969 non-null  float64
#  7   sqft_living15  21969 non-null  int64
#  8   sqft_lot15     21969 non-null  int64
#  9   date           21969 non-null  object
#  10  price          21969 non-null  float64
#  11  bedrooms       15273 non-null  float64
#  12  bathrooms      14353 non-null  float64
#  13  sqft_living    21969 non-null  int64
#  14  sqft_lot       21969 non-null  int64
#  15  floors         17107 non-null  float64
#  16  waterfront     21969 non-null  object
#  17  view           21969 non-null  int64
#  18  condition      21969 non-null  int64
#  19  grade          21969 non-null  int64
#  20  sqft_above     21969 non-null  int64
# dtypes: float64(6), int64(13), object(2)
# memory usage: 3.7+ MB

# %%
df['view'].value_counts()
# Out:
# 0    19829
# 2      965
# 3      516
# 1      334
# 4      325
# Name: view, dtype: int64

# %%
df = df[df['view'] <= 1]

# %%
df['view'].value_counts()
# Out:
# 0    19829
# 1      334
# Name: view, dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# 0    19789
# ?      373
# 1        1
# Name: waterfront, dtype: int64

# %%
df = df.drop(columns=['waterfront'])

# %%
df['condition'].value_counts()
# Out:
# 3    13191
# 4     5225
# 5     1532
# 2      185
# 1       30
# Name: condition, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8818
# 8     5566
# 9     2241
# 6     2056
# 10     887
# 11     264
# 5      249
# 12      45
# 4       28
# 13       5
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20163 entries, 0 to 21968
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20163 non-null  int64
#  1   sqft_basement  20163 non-null  int64
#  2   yr_built       20163 non-null  int64
#  3   yr_renovated   20163 non-null  int64
#  4   zipcode        20163 non-null  int64
#  5   lat            20163 non-null  float64
#  6   long           20163 non-null  float64
#  7   sqft_living15  20163 non-null  int64
#  8   sqft_lot15     20163 non-null  int64
#  9   date           20163 non-null  object
#  10  price          20163 non-null  float64
#  11  bedrooms       14035 non-null  float64
#  12  bathrooms      13152 non-null  float64
#  13  sqft_living    20163 non-null  int64
#  14  sqft_lot       20163 non-null  int64
#  15  floors         15666 non-null  float64
#  16  view           20163 non-null  int64
#  17  condition      20163 non-null  int64
#  18  grade          20163 non-null  int64
#  19  sqft_above     20163 non-null  int64
# dtypes: float64(6), int64(13), object(1)
# memory usage: 3.2+ MB

# %%
df['date'].value_counts()
# Out:
# 20140623T000000    131
# 20140708T000000    122
# 20140626T000000    121
# 20150428T000000    119
# 20140625T000000    116
#                   ...
# 20150110T000000      1
# 20141102T000000      1
# 20140517T000000      1
# 20150515T000000      1
# 20140727T000000      1
# Name: date, Length: 372, dtype: int64

# %%
df['date']=df['date'].map(lambda x: str(x).strip().split("T")[0])

# %%
df['date'].value_counts()
# Out:
# 20140623    131
# 20140708    122
# 20140626    121
# 20150428    119
# 20140625    116
#            ...
# 20150110      1
# 20141102      1
# 20140517      1
# 20150515      1
# 20140727      1
# Name: date, Length: 372, dtype: int64

# %%
rearrange_chars = lambda s: s[6:] + '/' +  s[4:6] + '/' + s[:4]
df['date'] = df['date'].apply(rearrange_chars)

# %%
df['date'].value_counts()
# Out:
# 23/06/2014    131
# 08/07/2014    122
# 26/06/2014    121
# 28/04/2015    119
# 25/06/2014    116
#              ...
# 10/01/2015      1
# 02/11/2014      1
# 17/05/2014      1
# 15/05/2015      1
# 27/07/2014      1
# Name: date, Length: 372, dtype: int64

# %%
df.nunique()
# Out:
# id               19651
# sqft_basement      258
# yr_built           116
# yr_renovated        68
# zipcode             70
# lat               4936
# long               725
# sqft_living15      731
# sqft_lot15        8053
# date               372
# price             3747
# bedrooms            12
# bathrooms            8
# sqft_living        941
# sqft_lot          9041
# floors               4
# view                 2
# condition            5
# grade               12
# sqft_above         881
# dtype: int64

# %%
df3 = pd.DataFrame(df, columns = ['sqft_living15','sqft_lot15','sqft_living','sqft_lot'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                  id  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  2.016300e+04   20163.000000  20163.000000  20163.000000  20163.000000
# mean   4.568489e+09     257.254476   1971.256757     73.157070  98076.890096
# std    2.872724e+09     404.282015     29.310773    375.084089     52.706678
# min    1.000102e+06       0.000000   1900.000000      0.000000  98001.000000
# 25%    2.115720e+09       0.000000   1952.000000      0.000000  98033.000000
# 50%    3.900500e+09       0.000000   1975.000000      0.000000  98065.000000
# 75%    7.300200e+09     500.000000   1997.000000      0.000000  98117.000000
# max    9.900000e+09    3000.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15         price  \
# count  20163.000000  20163.000000   20163.000000   20163.000000  2.016300e+04
# mean      47.559724   -122.211587    1929.031146   12139.004563  4.999817e+05
# std        0.139634      0.139701     646.290105   24951.135130  2.947602e+05
# min       47.155900   -122.519000     460.000000     651.000000  7.500000e+04
# 25%       47.465550   -122.324000    1460.000000    5060.000000  3.110000e+05
# 50%       47.571400   -122.225000    1790.000000    7560.000000  4.350000e+05
# 75%       47.680000   -122.124000    2271.500000    9880.000000  6.050000e+05
# max       47.777600   -121.315000    6210.000000  871200.000000  5.570000e+06
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  14035.000000  13152.000000  20163.000000  2.016300e+04  15666.000000
# mean       3.346705      2.008668   2001.697763  1.410702e+04      1.533704
# std        0.901874      0.716694    841.996878  3.665696e+04      0.563645
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      2.000000   1390.000000  5.000000e+03      1.000000
# 50%        3.000000      2.000000   1850.000000  7.519000e+03      1.000000
# 75%        4.000000      2.000000   2450.000000  1.030700e+04      2.000000
# max       11.000000      8.000000   9200.000000  1.164794e+06      4.000000
#
#                view     condition         grade    sqft_above
# count  20163.000000  20163.000000  20163.000000  20163.000000
# mean       0.016565      3.398949      7.563607   1744.443287
# std        0.127638      0.647340      1.114094    792.205187
# min        0.000000      1.000000      1.000000    290.000000
# 25%        0.000000      3.000000      7.000000   1170.000000
# 50%        0.000000      3.000000      7.000000   1520.000000
# 75%        0.000000      4.000000      8.000000   2150.000000
# max        1.000000      5.000000     13.000000   8020.000000

# %%
def replace_outliers_median(x):
    q1 = np.percentile(x, 25)
    q3 = np.percentile(x, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    x[x < lower_bound] = np.median(x)
    x[x > upper_bound] = np.median(x)
    return x

# Define a function to replace outliers with the mode for categorical variables
def replace_outliers_mode(x):
    mode = x.mode()[0]
    x[x != mode] = mode
    return x

# %%
# Apply the functions to the data
df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']] = df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']].apply(replace_outliers_median)

# %%
df3 = pd.DataFrame(df, columns = ['sqft_living15','sqft_lot15','sqft_living','sqft_lot'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Apply the functions to the data
df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']] = df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']].apply(replace_outliers_median)

# %%
df3 = pd.DataFrame(df, columns = ['sqft_living15','sqft_lot15','sqft_living','sqft_lot'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Apply the functions to the data
df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']] = df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']].apply(replace_outliers_median)

# %%
df3 = pd.DataFrame(df, columns = ['sqft_living15','sqft_lot15','sqft_living','sqft_lot'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Apply the functions to the data
df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']] = df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']].apply(replace_outliers_median)
# Apply the functions to the data
df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']] = df[['sqft_living15','sqft_lot15','sqft_living','sqft_lot']].apply(replace_outliers_median)

# %%
df3 = pd.DataFrame(df, columns = ['sqft_living15','sqft_lot15','sqft_living','sqft_lot'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
 
  
# plotting correlation heatmap
dataplot=sns.heatmap(df.corr())
plt.figure(figsize=(30, 15))
# displaying heatmap
plt.show()

# %%
df.nunique()
# Out:
# id               19651
# sqft_basement      258
# yr_built           116
# yr_renovated        68
# zipcode             70
# lat               4936
# long               725
# sqft_living15      559
# sqft_lot15        6118
# date               372
# price             3747
# bedrooms            12
# bathrooms            8
# sqft_living        725
# sqft_lot          6593
# floors               4
# view                 2
# condition            5
# grade               12
# sqft_above         881
# dtype: int64

# %%
df.head(20)
# Out:
#             id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0   7129300520              0      1955             0    98178  47.5112
# 1   6414100192            400      1951          1991    98125  47.7210
# 2   5631500400              0      1933             0    98028  47.7379
# 3   2487200875            910      1965             0    98136  47.5208
# 4   1954400510              0      1987             0    98074  47.6168
# 5   7237550310           1530      2001             0    98053  47.6561
# 6   1321400060              0      1995             0    98003  47.3097
# 7   2008000270              0      1963             0    98198  47.4095
# 8   2414600126            730      1960             0    98146  47.5123
# 9   3793500160              0      2003             0    98038  47.3684
# 10  1736800520           1700      1965             0    98007  47.6007
# 11  9212900260            300      1942             0    98115  47.6900
# 12   114101516              0      1927             0    98028  47.7558
# 13  6054650070              0      1977             0    98074  47.6127
# 14  1175000570              0      1900             0    98107  47.6700
# 16  1875500060              0      1994             0    98019  47.7277
# 17  6865200140              0      1916             0    98103  47.6648
# 18    16000397              0      1921             0    98002  47.3089
# 19  7983200060              0      1969             0    98003  47.3343
# 20  6300500875            760      1947             0    98133  47.7025
#
#        long  sqft_living15  sqft_lot15        date      price  bedrooms  \
# 0  -122.257           1340        5650  13/10/2014   221900.0       3.0
# 1  -122.319           1690        7639  09/12/2014   538000.0       3.0
# 2  -122.233           2720        8062  25/02/2015   180000.0       2.0
# 3  -122.393           1360        5000  09/12/2014   604000.0       4.0
# 4  -122.045           1800        7503  18/02/2015   510000.0       3.0
# 5  -122.005           1790        7560  12/05/2014  1225000.0       4.0
# 6  -122.327           2238        6819  27/06/2014   257500.0       3.0
# 7  -122.315           1650        9711  15/01/2015   291850.0       3.0
# 8  -122.337           1780        8113  15/04/2015   229500.0       3.0
# 9  -122.031           2390        7570  12/03/2015   323000.0       3.0
# 10 -122.145           2210        8925  03/04/2015   662500.0       3.0
# 11 -122.292           1330        6000  27/05/2014   468000.0       2.0
# 12 -122.229           1780       12697  28/05/2014   310000.0       3.0
# 13 -122.045           1370       10208  07/10/2014   400000.0       3.0
# 14 -122.394           1360        4850  12/03/2015   530000.0       5.0
# 16 -121.962           1890        7560  31/07/2014   395000.0       3.0
# 17 -122.343           1610        4300  29/05/2014   485000.0       4.0
# 18 -122.210           1060        5095  05/12/2014   189000.0       2.0
# 19 -122.306           1280        8850  24/04/2015   230000.0       3.0
# 20 -122.341           1400        4980  14/05/2014   385000.0       NaN
#
#     bathrooms  sqft_living  sqft_lot  floors  view  condition  grade  \
# 0         NaN         1180      5650     NaN     0          3      7
# 1         2.0         2570      7242     2.0     0          3      7
# 2         NaN          770     10000     NaN     0          3      6
# 3         NaN         1960      5000     NaN     0          5      7
# 4         2.0         1680      8080     1.0     0          3      8
# 5         4.0         1850      7519     1.0     0          3     11
# 6         NaN         1715      6819     2.0     0          3      7
# 7         NaN         1060      9711     1.0     0          3      7
# 8         1.0         1780      7470     1.0     0          3      7
# 9         2.0         1890      6560     2.0     0          3      7
# 10        NaN         3560      9796     NaN     0          3      8
# 11        1.0         1160      6000     1.0     0          4      7
# 12        1.0         1430      7519     NaN     0          4      7
# 13        2.0         1370      9680     1.0     0          4      7
# 14        NaN         1810      4850     2.0     0          3      7
# 16        2.0         1890      7519     2.0     0          3      7
# 17        1.0         1600      4300     2.0     0          4      7
# 18        1.0         1200      9850     1.0     0          4      7
# 19        NaN         1250      9774     NaN     0          4      7
# 20        2.0         1620      4980     1.0     0          4      7
#
#     sqft_above
# 0         1180
# 1         2170
# 2          770
# 3         1050
# 4         1680
# 5         3890
# 6         1715
# 7         1060
# 8         1050
# 9         1890
# 10        1860
# 11         860
# 12        1430
# 13        1370
# 14        1810
# 16        1890
# 17        1600
# 18        1200
# 19        1250
# 20         860

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(25,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
df.columns
# Out:
# Index(['id', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat',
#        'long', 'sqft_living15', 'sqft_lot15', 'date', 'price', 'bedrooms',
#        'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'view', 'condition',
#        'grade', 'sqft_above'],
#       dtype='object')

# %%
PlotBarCharts(inpData=df, colsToPlot=['sqft_living15','sqft_living'])

# %%
# Count the frequency of each unique value in the "category" column and select the top 10
top_categories = df['sqft_living'].value_counts().head(10)

# Plot the top 10 categories as a bar graph
top_categories.plot(kind='bar')

# Set the title and x-axis label
plt.title('Top 10 Categories')
plt.xlabel('sqft_living')

# Show the plot
plt.show()

# %%
# Count the frequency of each unique value in the "category" column and select the top 10
top_categories = df['sqft_living15'].value_counts().head(10)

# Plot the top 10 categories as a bar graph
top_categories.plot(kind='bar')

# Set the title and x-axis label
plt.title('Top 10 Categories')
plt.xlabel('sqft_living15')

# Show the plot
plt.show()

# %%
top10_cars = df['sqft_living'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['sqft_living'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['condition'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['condition'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['grade'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['grade'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['bedrooms'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['bedrooms'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['sqft_lot'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['sqft_lot'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
top10_cars = df['view'].value_counts().sort_values(ascending = False)[:10]
top10_mean_prices = [df[df['view'] == i]['price'].mean() for i in list(top10_cars.index)]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(121)
sns.barplot(top10_cars.index, top10_cars.values, palette='hot')
plt.xticks(rotation = 90)
plt.ylabel('# Cars')
plt.title('Distribution of Category')

ax2 = fig.add_subplot(122)
sns.lineplot(top10_cars.index, top10_mean_prices, color='r')
plt.xticks(rotation = 90)
plt.ylabel('Mean Prices')
plt.title("Categories and its Mean Prices")
plt.show()

# %%
df['bathrooms'].value_counts()
# Out:
# 2.0    8548
# 1.0    2569
# 3.0    1404
# 4.0     593
# 5.0      19
# 6.0      11
# 0.0       7
# 8.0       1
# Name: bathrooms, dtype: int64

# %%
df['floors'].value_counts()
# Out:
# 1.0    7839
# 2.0    7298
# 3.0     524
# 4.0       5
# Name: floors, dtype: int64

# %%
df.nunique()
# Out:
# id               19651
# sqft_basement      258
# yr_built           116
# yr_renovated        68
# zipcode             70
# lat               4936
# long               725
# sqft_living15      559
# sqft_lot15        6118
# date               372
# price             3747
# bedrooms            12
# bathrooms            8
# sqft_living        725
# sqft_lot          6593
# floors               4
# view                 2
# condition            5
# grade               12
# sqft_above         881
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20163 entries, 0 to 21968
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20163 non-null  int64
#  1   sqft_basement  20163 non-null  int64
#  2   yr_built       20163 non-null  int64
#  3   yr_renovated   20163 non-null  int64
#  4   zipcode        20163 non-null  int64
#  5   lat            20163 non-null  float64
#  6   long           20163 non-null  float64
#  7   sqft_living15  20163 non-null  int64
#  8   sqft_lot15     20163 non-null  int64
#  9   date           20163 non-null  object
#  10  price          20163 non-null  float64
#  11  bedrooms       14035 non-null  float64
#  12  bathrooms      13152 non-null  float64
#  13  sqft_living    20163 non-null  int64
#  14  sqft_lot       20163 non-null  int64
#  15  floors         15666 non-null  float64
#  16  view           20163 non-null  int64
#  17  condition      20163 non-null  int64
#  18  grade          20163 non-null  int64
#  19  sqft_above     20163 non-null  int64
# dtypes: float64(6), int64(13), object(1)
# memory usage: 3.2+ MB

# %%
df['floors'] = df['floors'].astype('category')
df['condition'] = df['condition'].astype('category')
df['grade'] = df['grade'].astype('category')
df['bedrooms'] = df['bedrooms'].astype('category')
df['bathrooms'] = df['bathrooms'].astype('category')

# %%
df = df.drop(columns=['view'])

# %%
from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import StandardScaler, OneHotEncoder
# create a label encoder object
le = LabelEncoder()

# apply label encoding to each categorical variable
df['date'] = le.fit_transform(df['date'])
df['zipcode'] = le.fit_transform(df['zipcode'])

# %%
df['date'] = df['date'].astype('category')
df['zipcode'] = df['zipcode'].astype('category')

# %%
df.isnull().sum()
# Out:
# id                  0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# bedrooms         6128
# bathrooms        7011
# sqft_living         0
# sqft_lot            0
# floors           4497
# condition           0
# grade               0
# sqft_above          0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df
# Out:
#                  id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7.129301e+09            0.0    1955.0           0.0     66.0  47.5112
# 1      6.414100e+09          400.0    1951.0        1991.0     55.0  47.7210
# 2      5.631500e+09            0.0    1933.0           0.0     16.0  47.7379
# 3      2.487201e+09          910.0    1965.0           0.0     58.0  47.5208
# 4      1.954401e+09            0.0    1987.0           0.0     37.0  47.6168
# ...             ...            ...       ...           ...      ...      ...
# 20158  2.630000e+08            0.0    2009.0           0.0     42.0  47.6993
# 20159  6.600060e+09            0.0    2014.0           0.0     60.0  47.5107
# 20160  1.523300e+09            0.0    2009.0           0.0     59.0  47.5944
# 20161  2.913101e+08            0.0    2004.0           0.0     15.0  47.5345
# 20162  1.523300e+09            0.0    2008.0           0.0     59.0  47.5941
#
#           long  sqft_living15  sqft_lot15   date     price  bedrooms  \
# 0     -122.257         1340.0      5650.0  160.0  221900.0  3.000000
# 1     -122.319         1690.0      7639.0  111.0  538000.0  3.000000
# 2     -122.233         2720.0      8062.0  298.0  180000.0  2.000000
# 3     -122.393         1360.0      5000.0  111.0  604000.0  4.000000
# 4     -122.045         1800.0      7503.0  213.0  510000.0  3.000000
# ...        ...            ...         ...    ...       ...       ...
# 20158 -122.346         1530.0      1509.0  252.0  360000.0  3.000000
# 20159 -122.362         1830.0      7200.0  273.0  400000.0  4.000000
# 20160 -122.299         1020.0      2007.0  277.0  402101.0  2.333333
# 20161 -122.069         1410.0      1287.0  189.0  400000.0  3.000000
# 20162 -122.299         1020.0      1357.0  186.0  325000.0  2.000000
#
#        bathrooms  sqft_living  sqft_lot    floors  condition  grade  \
# 0       1.333333       1180.0    5650.0  1.000000        3.0    7.0
# 1       2.000000       2570.0    7242.0  2.000000        3.0    7.0
# 2       2.000000        770.0   10000.0  1.333333        3.0    6.0
# 3       3.000000       1960.0    5000.0  2.000000        5.0    7.0
# 4       2.000000       1680.0    8080.0  1.000000        3.0    8.0
# ...          ...          ...       ...       ...        ...    ...
# 20158   2.000000       1530.0    1131.0  3.000000        3.0    8.0
# 20159   2.000000       2310.0    5813.0  2.000000        3.0    8.0
# 20160   1.000000       1020.0    1350.0  2.000000        3.0    7.0
# 20161   2.000000       1600.0    2388.0  2.000000        3.0    8.0
# 20162   1.000000       1020.0    1076.0  2.000000        3.0    7.0
#
#        sqft_above
# 0          1180.0
# 1          2170.0
# 2           770.0
# 3          1050.0
# 4          1680.0
# ...           ...
# 20158      1530.0
# 20159      2310.0
# 20160      1020.0
# 20161      1600.0
# 20162      1020.0
#
# [20163 rows x 19 columns]

# %%
df3 = pd.DataFrame(df, columns = ['7','8','13','14'])  
plt.figure(figsize = (10, 20)) 
  
df3.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# id               0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# condition        0
# grade            0
# sqft_above       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20163 entries, 0 to 20162
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20163 non-null  float64
#  1   sqft_basement  20163 non-null  float64
#  2   yr_built       20163 non-null  float64
#  3   yr_renovated   20163 non-null  float64
#  4   zipcode        20163 non-null  float64
#  5   lat            20163 non-null  float64
#  6   long           20163 non-null  float64
#  7   sqft_living15  20163 non-null  float64
#  8   sqft_lot15     20163 non-null  float64
#  9   date           20163 non-null  float64
#  10  price          20163 non-null  float64
#  11  bedrooms       20163 non-null  float64
#  12  bathrooms      20163 non-null  float64
#  13  sqft_living    20163 non-null  float64
#  14  sqft_lot       20163 non-null  float64
#  15  floors         20163 non-null  float64
#  16  condition      20163 non-null  float64
#  17  grade          20163 non-null  float64
#  18  sqft_above     20163 non-null  float64
# dtypes: float64(19)
# memory usage: 2.9 MB

# %%
df
# Out:
#                  id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7.129301e+09            0.0    1955.0           0.0     66.0  47.5112
# 1      6.414100e+09          400.0    1951.0        1991.0     55.0  47.7210
# 2      5.631500e+09            0.0    1933.0           0.0     16.0  47.7379
# 3      2.487201e+09          910.0    1965.0           0.0     58.0  47.5208
# 4      1.954401e+09            0.0    1987.0           0.0     37.0  47.6168
# ...             ...            ...       ...           ...      ...      ...
# 20158  2.630000e+08            0.0    2009.0           0.0     42.0  47.6993
# 20159  6.600060e+09            0.0    2014.0           0.0     60.0  47.5107
# 20160  1.523300e+09            0.0    2009.0           0.0     59.0  47.5944
# 20161  2.913101e+08            0.0    2004.0           0.0     15.0  47.5345
# 20162  1.523300e+09            0.0    2008.0           0.0     59.0  47.5941
#
#           long  sqft_living15  sqft_lot15   date     price  bedrooms  \
# 0     -122.257         1340.0      5650.0  160.0  221900.0  3.000000
# 1     -122.319         1690.0      7639.0  111.0  538000.0  3.000000
# 2     -122.233         2720.0      8062.0  298.0  180000.0  2.000000
# 3     -122.393         1360.0      5000.0  111.0  604000.0  4.000000
# 4     -122.045         1800.0      7503.0  213.0  510000.0  3.000000
# ...        ...            ...         ...    ...       ...       ...
# 20158 -122.346         1530.0      1509.0  252.0  360000.0  3.000000
# 20159 -122.362         1830.0      7200.0  273.0  400000.0  4.000000
# 20160 -122.299         1020.0      2007.0  277.0  402101.0  2.333333
# 20161 -122.069         1410.0      1287.0  189.0  400000.0  3.000000
# 20162 -122.299         1020.0      1357.0  186.0  325000.0  2.000000
#
#        bathrooms  sqft_living  sqft_lot    floors  condition  grade  \
# 0       1.333333       1180.0    5650.0  1.000000        3.0    7.0
# 1       2.000000       2570.0    7242.0  2.000000        3.0    7.0
# 2       2.000000        770.0   10000.0  1.333333        3.0    6.0
# 3       3.000000       1960.0    5000.0  2.000000        5.0    7.0
# 4       2.000000       1680.0    8080.0  1.000000        3.0    8.0
# ...          ...          ...       ...       ...        ...    ...
# 20158   2.000000       1530.0    1131.0  3.000000        3.0    8.0
# 20159   2.000000       2310.0    5813.0  2.000000        3.0    8.0
# 20160   1.000000       1020.0    1350.0  2.000000        3.0    7.0
# 20161   2.000000       1600.0    2388.0  2.000000        3.0    8.0
# 20162   1.000000       1020.0    1076.0  2.000000        3.0    7.0
#
#        sqft_above
# 0          1180.0
# 1          2170.0
# 2           770.0
# 3          1050.0
# 4          1680.0
# ...           ...
# 20158      1530.0
# 20159      2310.0
# 20160      1020.0
# 20161      1600.0
# 20162      1020.0
#
# [20163 rows x 19 columns]

# %%
df[df['sqft_basement'] == 0]
# Out:
#                  id  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7.129301e+09            0.0    1955.0           0.0     66.0  47.5112
# 2      5.631500e+09            0.0    1933.0           0.0     16.0  47.7379
# 4      1.954401e+09            0.0    1987.0           0.0     37.0  47.6168
# 6      1.321400e+09            0.0    1995.0           0.0      2.0  47.3097
# 7      2.008000e+09            0.0    1963.0           0.0     68.0  47.4095
# ...             ...            ...       ...           ...      ...      ...
# 20158  2.630000e+08            0.0    2009.0           0.0     42.0  47.6993
# 20159  6.600060e+09            0.0    2014.0           0.0     60.0  47.5107
# 20160  1.523300e+09            0.0    2009.0           0.0     59.0  47.5944
# 20161  2.913101e+08            0.0    2004.0           0.0     15.0  47.5345
# 20162  1.523300e+09            0.0    2008.0           0.0     59.0  47.5941
#
#           long  sqft_living15  sqft_lot15   date     price  bedrooms  \
# 0     -122.257         1340.0      5650.0  160.0  221900.0  3.000000
# 2     -122.233         2720.0      8062.0  298.0  180000.0  2.000000
# 4     -122.045         1800.0      7503.0  213.0  510000.0  3.000000
# 6     -122.327         2238.0      6819.0  326.0  257500.0  3.000000
# 7     -122.315         1650.0      9711.0  176.0  291850.0  3.000000
# ...        ...            ...         ...    ...       ...       ...
# 20158 -122.346         1530.0      1509.0  252.0  360000.0  3.000000
# 20159 -122.362         1830.0      7200.0  273.0  400000.0  4.000000
# 20160 -122.299         1020.0      2007.0  277.0  402101.0  2.333333
# 20161 -122.069         1410.0      1287.0  189.0  400000.0  3.000000
# 20162 -122.299         1020.0      1357.0  186.0  325000.0  2.000000
#
#        bathrooms  sqft_living  sqft_lot    floors  condition  grade  \
# 0       1.333333       1180.0    5650.0  1.000000        3.0    7.0
# 2       2.000000        770.0   10000.0  1.333333        3.0    6.0
# 4       2.000000       1680.0    8080.0  1.000000        3.0    8.0
# 6       2.000000       1715.0    6819.0  2.000000        3.0    7.0
# 7       2.000000       1060.0    9711.0  1.000000        3.0    7.0
# ...          ...          ...       ...       ...        ...    ...
# 20158   2.000000       1530.0    1131.0  3.000000        3.0    8.0
# 20159   2.000000       2310.0    5813.0  2.000000        3.0    8.0
# 20160   1.000000       1020.0    1350.0  2.000000        3.0    7.0
# 20161   2.000000       1600.0    2388.0  2.000000        3.0    8.0
# 20162   1.000000       1020.0    1076.0  2.000000        3.0    7.0
#
#        sqft_above
# 0          1180.0
# 2           770.0
# 4          1680.0
# 6          1715.0
# 7          1060.0
# ...           ...
# 20158      1530.0
# 20159      2310.0
# 20160      1020.0
# 20161      1600.0
# 20162      1020.0
#
# [12757 rows x 19 columns]

# %%
df = df.drop(columns=['sqft_basement'])

# %%
df[df['yr_renovated'] == 0]
# Out:
#                  id  yr_built  yr_renovated  zipcode      lat     long  \
# 0      7.129301e+09    1955.0           0.0     66.0  47.5112 -122.257
# 2      5.631500e+09    1933.0           0.0     16.0  47.7379 -122.233
# 3      2.487201e+09    1965.0           0.0     58.0  47.5208 -122.393
# 4      1.954401e+09    1987.0           0.0     37.0  47.6168 -122.045
# 5      7.237550e+09    2001.0           0.0     29.0  47.6561 -122.005
# ...             ...       ...           ...      ...      ...      ...
# 20158  2.630000e+08    2009.0           0.0     42.0  47.6993 -122.346
# 20159  6.600060e+09    2014.0           0.0     60.0  47.5107 -122.362
# 20160  1.523300e+09    2009.0           0.0     59.0  47.5944 -122.299
# 20161  2.913101e+08    2004.0           0.0     15.0  47.5345 -122.069
# 20162  1.523300e+09    2008.0           0.0     59.0  47.5941 -122.299
#
#        sqft_living15  sqft_lot15   date      price  bedrooms  bathrooms  \
# 0             1340.0      5650.0  160.0   221900.0  3.000000   1.333333
# 2             2720.0      8062.0  298.0   180000.0  2.000000   2.000000
# 3             1360.0      5000.0  111.0   604000.0  4.000000   3.000000
# 4             1800.0      7503.0  213.0   510000.0  3.000000   2.000000
# 5             1790.0      7560.0  141.0  1225000.0  4.000000   4.000000
# ...              ...         ...    ...        ...       ...        ...
# 20158         1530.0      1509.0  252.0   360000.0  3.000000   2.000000
# 20159         1830.0      7200.0  273.0   400000.0  4.000000   2.000000
# 20160         1020.0      2007.0  277.0   402101.0  2.333333   1.000000
# 20161         1410.0      1287.0  189.0   400000.0  3.000000   2.000000
# 20162         1020.0      1357.0  186.0   325000.0  2.000000   1.000000
#
#        sqft_living  sqft_lot    floors  condition  grade  sqft_above
# 0           1180.0    5650.0  1.000000        3.0    7.0      1180.0
# 2            770.0   10000.0  1.333333        3.0    6.0       770.0
# 3           1960.0    5000.0  2.000000        5.0    7.0      1050.0
# 4           1680.0    8080.0  1.000000        3.0    8.0      1680.0
# 5           1850.0    7519.0  1.000000        3.0   11.0      3890.0
# ...            ...       ...       ...        ...    ...         ...
# 20158       1530.0    1131.0  3.000000        3.0    8.0      1530.0
# 20159       2310.0    5813.0  2.000000        3.0    8.0      2310.0
# 20160       1020.0    1350.0  2.000000        3.0    7.0      1020.0
# 20161       1600.0    2388.0  2.000000        3.0    8.0      1600.0
# 20162       1020.0    1076.0  2.000000        3.0    7.0      1020.0
#
# [19424 rows x 18 columns]

# %%
df = df.drop(columns=['yr_renovated'])

# %%
df.columns
# Out:
# Index(['id', 'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id      yr_built       zipcode           lat          long  \
# count  2.016300e+04  20163.000000  20163.000000  20163.000000  20163.000000
# mean   4.568489e+09   1971.256757     34.840252     47.559724   -122.211587
# std    2.872724e+09     29.310773     19.044790      0.139634      0.139701
# min    1.000102e+06   1900.000000      0.000000     47.155900   -122.519000
# 25%    2.115720e+09   1952.000000     21.000000     47.465550   -122.324000
# 50%    3.900500e+09   1975.000000     34.000000     47.571400   -122.225000
# 75%    7.300200e+09   1997.000000     51.000000     47.680000   -122.124000
# max    9.900000e+09   2015.000000     69.000000     47.777600   -121.315000
#
#        sqft_living15    sqft_lot15          date         price      bedrooms  \
# count   20163.000000  20163.000000  20163.000000  2.016300e+04  20163.000000
# mean     1846.364827   6923.375490    187.079006  4.999817e+05      3.338524
# std       517.933505   2575.861601    106.019864  2.947602e+05      0.823650
# min       460.000000    651.000000      0.000000  7.500000e+04      0.000000
# 25%      1460.000000   5060.000000     95.000000  3.110000e+05      3.000000
# 50%      1790.000000   7560.000000    193.000000  4.350000e+05      3.000000
# 75%      2170.000000   8400.000000    278.000000  6.050000e+05      4.000000
# max      3230.000000  13404.000000    371.000000  5.570000e+06     11.000000
#
#           bathrooms   sqft_living      sqft_lot        floors     condition  \
# count  20163.000000  20163.000000  20163.000000  20163.000000  20163.000000
# mean       2.005059   1911.191192   6861.693548      1.532989      3.398949
# std        0.647687    688.639792   2659.493447      0.537761      0.647340
# min        0.000000    290.000000    520.000000      1.000000      1.000000
# 25%        2.000000   1390.000000   5000.000000      1.000000      3.000000
# 50%        2.000000   1850.000000   7519.000000      1.333333      3.000000
# 75%        2.000000   2350.000000   8336.000000      2.000000      4.000000
# max        8.000000   3790.000000  13430.000000      4.000000      5.000000
#
#               grade    sqft_above
# count  20163.000000  20163.000000
# mean       7.563607   1744.443287
# std        1.114094    792.205187
# min        1.000000    290.000000
# 25%        7.000000   1170.000000
# 50%        7.000000   1520.000000
# 75%        8.000000   2150.000000
# max       13.000000   8020.000000

# %%
ContinuousCols=['yr_built','sqft_living15', 'sqft_lot15', 'sqft_living', 'sqft_lot','sqft_above','price','lat',
       'long']

# %%
### Sandardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMAx normalization
PredictorScaler=StandardScaler()
#PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(df[ContinuousCols])

# Generating the standardized values of X
res=PredictorScalerFit.transform(df[ContinuousCols])

# %%
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler().fit(res)
res = transformer.transform(res)

# %%
df4 = pd.DataFrame(res, columns =['yr_built.1','sqft_living15.1', 'sqft_lot15.1', 'sqft_living.1', 'sqft_lot.1','sqft_above.1','Price','lat.1',
       'long.1'])

# %%
df = pd.concat([df4.reset_index(drop=True), df.reset_index(drop=True)], axis=1)

# %%
delete_cols = ['yr_built','sqft_living15', 'sqft_lot15', 'sqft_living', 'sqft_lot','sqft_above','price','lat',
       'long']

df = df.drop(columns=delete_cols)

# %%
df
# Out:
#        yr_built.1  sqft_living15.1  sqft_lot15.1  sqft_living.1  sqft_lot.1  \
# 0       -0.444444        -0.633803     -0.571856      -0.697917   -0.560252
# 1       -0.533333        -0.140845      0.023653       0.750000   -0.083034
# 2       -0.933333         1.309859      0.150299      -1.125000    0.743705
# 3       -0.222222        -0.605634     -0.766467       0.114583   -0.755096
# 4        0.266667         0.014085     -0.017066      -0.177083    0.168165
# ...           ...              ...           ...            ...         ...
# 20158    0.755556        -0.366197     -1.811677      -0.333333   -1.914868
# 20159    0.866667         0.056338     -0.107784       0.479167   -0.511391
# 20160    0.755556        -1.084507     -1.662575      -0.864583   -1.849221
# 20161    0.644444        -0.535211     -1.878144      -0.260417   -1.538070
# 20162    0.733333        -1.084507     -1.857186      -0.864583   -1.931355
#
#        sqft_above.1     Price     lat.1  long.1            id  zipcode   date  \
# 0         -0.346939 -0.724830 -0.280718  -0.160  7.129301e+09     66.0  160.0
# 1          0.663265  0.350340  0.697599  -0.470  6.414100e+09     55.0  111.0
# 2         -0.765306 -0.867347  0.776405  -0.040  5.631500e+09     16.0  298.0
# 3         -0.479592  0.574830 -0.235952  -0.840  2.487201e+09     58.0  111.0
# 4          0.163265  0.255102  0.211704   0.900  1.954401e+09     37.0  213.0
# ...             ...       ...       ...     ...           ...      ...    ...
# 20158      0.010204 -0.255102  0.596409  -0.605  2.630000e+08     42.0  252.0
# 20159      0.806122 -0.119048 -0.283050  -0.685  6.600060e+09     60.0  273.0
# 20160     -0.510204 -0.111901  0.107251  -0.370  1.523300e+09     59.0  277.0
# 20161      0.081633 -0.119048 -0.172068   0.780  2.913101e+08     15.0  189.0
# 20162     -0.510204 -0.374150  0.105852  -0.370  1.523300e+09     59.0  186.0
#
#        bedrooms  bathrooms    floors  condition  grade
# 0      3.000000   1.333333  1.000000        3.0    7.0
# 1      3.000000   2.000000  2.000000        3.0    7.0
# 2      2.000000   2.000000  1.333333        3.0    6.0
# 3      4.000000   3.000000  2.000000        5.0    7.0
# 4      3.000000   2.000000  1.000000        3.0    8.0
# ...         ...        ...       ...        ...    ...
# 20158  3.000000   2.000000  3.000000        3.0    8.0
# 20159  4.000000   2.000000  2.000000        3.0    8.0
# 20160  2.333333   1.000000  2.000000        3.0    7.0
# 20161  3.000000   2.000000  2.000000        3.0    8.0
# 20162  2.000000   1.000000  2.000000        3.0    7.0
#
# [20163 rows x 17 columns]

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
# Calling the function to check which categorical variables are correlated with target
# Calling the function to check which categorical variables are correlated with target
CategoricalPredictorList=['floors', 'condition', 'grade','bedrooms','bathrooms',
       'zipcode','date']
FunctionAnova(inpData=df, 
              TargetVariable='Price', 
              CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# floors is correlated with Price | P-Value: 0.0
# condition is correlated with Price | P-Value: 6.085230120030898e-35
# grade is correlated with Price | P-Value: 0.0
# bedrooms is correlated with Price | P-Value: 0.0
# bathrooms is correlated with Price | P-Value: 0.0
# zipcode is correlated with Price | P-Value: 0.0
# date is correlated with Price | P-Value: 4.572325859436735e-05
# ['floors', 'condition', 'grade', 'bedrooms', 'bathrooms', 'zipcode', 'date']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20163 entries, 0 to 20162
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   yr_built.1       20163 non-null  float64
#  1   sqft_living15.1  20163 non-null  float64
#  2   sqft_lot15.1     20163 non-null  float64
#  3   sqft_living.1    20163 non-null  float64
#  4   sqft_lot.1       20163 non-null  float64
#  5   sqft_above.1     20163 non-null  float64
#  6   Price            20163 non-null  float64
#  7   lat.1            20163 non-null  float64
#  8   long.1           20163 non-null  float64
#  9   id               20163 non-null  float64
#  10  zipcode          20163 non-null  float64
#  11  date             20163 non-null  float64
#  12  bedrooms         20163 non-null  float64
#  13  bathrooms        20163 non-null  float64
#  14  floors           20163 non-null  float64
#  15  condition        20163 non-null  float64
#  16  grade            20163 non-null  float64
# dtypes: float64(17)
# memory usage: 2.6 MB

# %%
# Calculating correlation matrix
ContinuousCols=['yr_built.1','sqft_living15.1', 'sqft_lot15.1', 'sqft_living.1', 'sqft_lot.1','sqft_above.1','Price','lat.1',
       'long.1']

# Creating the correlation matrix
CorrelationData=df[ContinuousCols].corr()
CorrelationData
# Out:
#                  yr_built.1  sqft_living15.1  sqft_lot15.1  sqft_living.1  \
# yr_built.1         1.000000         0.334788     -0.029016       0.335400
# sqft_living15.1    0.334788         1.000000      0.228472       0.640236
# sqft_lot15.1      -0.029016         0.228472      1.000000       0.165166
# sqft_living.1      0.335400         0.640236      0.165166       1.000000
# sqft_lot.1        -0.047893         0.216614      0.852953       0.182087
# sqft_above.1       0.445444         0.563509      0.161959       0.701603
# Price              0.080707         0.380725      0.017753       0.454988
# lat.1             -0.149401         0.010894     -0.131217       0.029603
# long.1             0.407771         0.343217      0.239323       0.265368
#
#                  sqft_lot.1  sqft_above.1     Price     lat.1    long.1
# yr_built.1        -0.047893      0.445444  0.080707 -0.149401  0.407771
# sqft_living15.1    0.216614      0.563509  0.380725  0.010894  0.343217
# sqft_lot15.1       0.852953      0.161959  0.017753 -0.131217  0.239323
# sqft_living.1      0.182087      0.701603  0.454988  0.029603  0.265368
# sqft_lot.1         1.000000      0.173891  0.018845 -0.140755  0.243489
# sqft_above.1       0.173891      1.000000  0.603669 -0.006288  0.371533
# Price              0.018845      0.603669  1.000000  0.356743  0.063665
# lat.1             -0.140755     -0.006288  0.356743  1.000000 -0.127262
# long.1             0.243489      0.371533  0.063665 -0.127262  1.000000

# %%
# Filtering only those columns where absolute correlation > 0.5 with Target Variable
# reduce the 0.5 threshold if no variable is selected
CorrelationData['Price'][abs(CorrelationData['Price']) > 0.3 ]
# Out:
# sqft_living15.1    0.380725
# sqft_living.1      0.454988
# sqft_above.1       0.603669
# Price              1.000000
# lat.1              0.356743
# Name: Price, dtype: float64

# %%
SelectedColumns=['sqft_living15.1','sqft_living.1','sqft_above.1', 'lat.1','floors', 'condition', 'grade','bathrooms', 'bedrooms', 'zipcode', 'date','Price']

# Selecting final columns
df=df[SelectedColumns]
df.head()
# Out:
#    sqft_living15.1  sqft_living.1  sqft_above.1     lat.1    floors  \
# 0        -0.633803      -0.697917     -0.346939 -0.280718  1.000000
# 1        -0.140845       0.750000      0.663265  0.697599  2.000000
# 2         1.309859      -1.125000     -0.765306  0.776405  1.333333
# 3        -0.605634       0.114583     -0.479592 -0.235952  2.000000
# 4         0.014085      -0.177083      0.163265  0.211704  1.000000
#
#    condition  grade  bathrooms  bedrooms  zipcode   date     Price
# 0        3.0    7.0   1.333333       3.0     66.0  160.0 -0.724830
# 1        3.0    7.0   2.000000       3.0     55.0  111.0  0.350340
# 2        3.0    6.0   2.000000       2.0     16.0  298.0 -0.867347
# 3        5.0    7.0   3.000000       4.0     58.0  111.0  0.574830
# 4        3.0    8.0   2.000000       3.0     37.0  213.0  0.255102

# %%
df
# Out:
#        sqft_living15.1  sqft_living.1  sqft_above.1     lat.1    floors  \
# 0            -0.633803      -0.697917     -0.346939 -0.280718  1.000000
# 1            -0.140845       0.750000      0.663265  0.697599  2.000000
# 2             1.309859      -1.125000     -0.765306  0.776405  1.333333
# 3            -0.605634       0.114583     -0.479592 -0.235952  2.000000
# 4             0.014085      -0.177083      0.163265  0.211704  1.000000
# ...                ...            ...           ...       ...       ...
# 20158        -0.366197      -0.333333      0.010204  0.596409  3.000000
# 20159         0.056338       0.479167      0.806122 -0.283050  2.000000
# 20160        -1.084507      -0.864583     -0.510204  0.107251  2.000000
# 20161        -0.535211      -0.260417      0.081633 -0.172068  2.000000
# 20162        -1.084507      -0.864583     -0.510204  0.105852  2.000000
#
#        condition  grade  bathrooms  bedrooms  zipcode   date     Price
# 0            3.0    7.0   1.333333  3.000000     66.0  160.0 -0.724830
# 1            3.0    7.0   2.000000  3.000000     55.0  111.0  0.350340
# 2            3.0    6.0   2.000000  2.000000     16.0  298.0 -0.867347
# 3            5.0    7.0   3.000000  4.000000     58.0  111.0  0.574830
# 4            3.0    8.0   2.000000  3.000000     37.0  213.0  0.255102
# ...          ...    ...        ...       ...      ...    ...       ...
# 20158        3.0    8.0   2.000000  3.000000     42.0  252.0 -0.255102
# 20159        3.0    8.0   2.000000  4.000000     60.0  273.0 -0.119048
# 20160        3.0    7.0   1.000000  2.333333     59.0  277.0 -0.111901
# 20161        3.0    8.0   2.000000  3.000000     15.0  189.0 -0.119048
# 20162        3.0    7.0   1.000000  2.000000     59.0  186.0 -0.374150
#
# [20163 rows x 12 columns]

# %%
 
  
# plotting correlation heatmap
dataplot=sns.heatmap(df.corr())
  
# displaying heatmap
plt.show()

# %%
df = df.drop(columns=['sqft_above.1'])

# %%
df = df.drop(columns = ['zipcode'])

# %%
df3 = df.sample(frac = 1)

# %%
X = np.array(df3.drop(["Price"],1))
print("Shape of X:",X.shape)
print(X)
# Out:
# Shape of X: (20163, 9)
# [[-2.67605634e-01 -3.43750000e-01 -2.11704360e-01 ...  2.00000000e+00
#    4.66666667e+00  2.85000000e+02]
#  [-1.12676056e+00 -8.85416667e-01 -1.27955234e+00 ...  1.66666667e+00
#    2.00000000e+00  3.41000000e+02]
#  [-2.95774648e-01 -7.91666667e-01  5.68897179e-01 ...  2.00000000e+00
#    3.33333333e+00  5.30000000e+01]
#  ...
#  [ 0.00000000e+00  2.00000000e+00  3.55327582e-01 ...  4.00000000e+00
#    3.33333333e+00  1.08000000e+02]
#  [ 3.09859155e-01  2.29166667e-01 -2.99370483e-01 ...  2.00000000e+00
#    3.66666667e+00  1.36000000e+02]
#  [-4.92957746e-01 -4.79166667e-01  9.53135929e-01 ...  2.00000000e+00
#    3.00000000e+00  3.36000000e+02]]

# %%
y = np.array(df3["Price"])
print("Shape of y:",y.shape)
print(y)
# Out:
# Shape of y: (20163,)
# [-0.35714286 -0.93539116  0.83333333 ...  2.27721088 -0.21428571
#  -0.46258503]

# %%
size = X.shape[0]
X_train = X[:int(0.7 * size),:]
X_test = X[int(0.7 * size):,:]
y_train = y[:int(0.7 * size)]
y_test = y[int(0.7 * size):]

# %%
#Standardizing the X_train and X_test daatsets
mu = np.mean(X_train, 0)
sigma = np.std(X_train, 0)

X_train = (X_train - mu ) / sigma

#We use the same mean and SD as the one of X_train as we dont know the mean of X_test
X_test = (X_test - mu ) / sigma

#Standardizing the y_train data
mu_y = np.mean(y_train, 0)
sigma_y = np.std(y_train, 0, ddof = 0)

y_train = (y_train - mu_y ) / sigma_y

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14114, 9)
# (6049, 9)
# (14114,)
# (6049,)

# %%
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)
y_pred = np.zeros(y_test.shape)
y_train.shape, y_test.shape,y_pred.shape
# Out:
# ((14114, 1), (6049, 1), (6049, 1))

# %%
n_neigh = 13
for row in range(len(X_test)):
    euclidian_distance = np.sqrt(np.sum((X_train - X_test[row])**2, axis = 1 ))
    y_pred[row] = np.mean(y_train[np.argsort(euclidian_distance, axis = 0)[:n_neigh]])* sigma_y + mu_y
    
#Finding the root mean squared error 

RMSE = np.sqrt(np.mean((y_pred - y_test)**2))
print(RMSE)
# Out:
# 0.5512648261172179

# %%
# Calculate mean absolute error
mae = np.mean(np.abs(y_test - y_pred))

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.3222123392867199

# %%
# We are setting a range of K values and calculating the RMSE for each of them. This way we can chose the optimal K value
k_list = [x for x in range(1,50,1)]

# Calculating the distance matrix using numpy broadcasting technique 
distance = np.sqrt(((X_train[:, :, None] - X_test[:, :, None].T) ** 2).sum(1))

#Sorting each data points of the distance matrix to reduce computational effort 
sorted_distance = np.argsort(distance, axis = 0)

#The knn function takes in the sorted distance and returns the RMSE of the 
def knn(X_train,X_test,y_train,y_test,sorted_distance,k):
    y_pred = np.zeros(y_test.shape)
    for row in range(len(X_test)):
        
        #Transforming the y_train values to adjust the scale. 
        y_pred[row] = np.mean(y_train[sorted_distance[:,row][:k]])* sigma_y + mu_y

    RMSE = np.sqrt(np.mean((y_test - y_pred)**2))
    return RMSE

#Storing the RMSE values in a list for each k value 
rmse_list = []
for i in k_list:
    rmse_list.append(knn(X_train,X_test,y_train,y_test,sorted_distance,i))

# %%
#Finding the optimal K value
min_rmse_k_value = k_list[rmse_list.index(min(rmse_list))]

#Finding the lowest possible RMSE
optimal_RMSE = knn(X_train,X_test,y_train,y_test,sorted_distance,min_rmse_k_value)
optimal_RMSE
# Out:
# 0.5447781125823878

# %%
min_rmse_k_value
# Out:
# 19

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score,mean_absolute_error

print(np.sqrt(mean_squared_error(y_test,y_pred))) 
r2scr = print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.5512648261172179
# 0.6858787052798627
# 0.3222123392867199

# %%
from sklearn.neighbors import KNeighborsRegressor
RegModel = KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.model_selection import GridSearchCV
param={'n_neighbors': range(1,50)}
grid_kn=GridSearchCV(estimator=RegModel,param_grid=param,scoring='neg_mean_squared_error',cv=5,verbose=1,n_jobs=-1)
grid_kn.fit(X_train,y_train)
print('Best K For Model is: ',grid_kn.best_params_)
print('Best Score is: ',grid_kn.best_score_)
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# Best K For Model is:  {'n_neighbors': 9}
# Best Score is:  -0.3158783925789792

# %%
KNN=RegModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

# %%
from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))
# Out:
# R2 Value: 0.8236557974974246
